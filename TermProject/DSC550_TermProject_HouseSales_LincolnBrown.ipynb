# %% [markdown]
# ## Housing Sale Price Predictions
#
# ### Term Project
#
# ## Lincoln Brown
#
# ## DSC550-T302
#
# ## Professor Werner

# %% [markdown]
# ## Sales Data DataFrames

# %%
import pandas as pd
import os
import numpy as np
import re

# %%
files = os.listdir()
file_list = []
years = []
df_list = []

# %%
for f in files:
    if f.__contains__('Resi'):
        file_list.append(f)
        pattern = "(\d{4})-(\d{4})"
        pattern = re.compile(pattern)
        [f_years] = pattern.findall(f)
        print(f_years)
        years.append(f_years)
# Out:
# ('2014', '2016')
# ('2017', '2019')
# ('2015', '2017')
# ('2018', '2020')
# ('2019', '2021')
# ('2016', '2018')
# ('2020', '2022')

# %%
df_list = []
df_14_16 = pd.read_excel(file_list[0], header=2, dtype={"Parcel ID": str})
df_list.append(df_14_16)
df_17_19 = pd.read_excel(file_list[1], header=2, dtype={"Parcel ID": str})
df_list.append(df_17_19)
df_15_17 = pd.read_excel(file_list[2], header=2, dtype={"Parcel ID": str})
df_list.append(df_15_17)
df_18_20 = pd.read_excel(file_list[3], header=2, dtype={"Parcel ID": str})
df_list.append(df_18_20)
df_19_21 = pd.read_excel(file_list[4], header=2, dtype={"Parcel ID": str})
df_list.append(df_19_21)
df_16_18 = pd.read_excel(file_list[5], header=2, dtype={"Parcel ID": str})
df_list.append(df_16_18)
df_20_22 = pd.read_excel(file_list[6], header=2, dtype={"Parcel ID": str})
df_list.append(df_20_22)
# Out:
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
for df in df_list:
    display(df)
# Out:
#     Sale Date  Parcel ID                     Seller  \
# 0  2014-10-17  530041421      Robert & Denise Waite
# 1  2014-10-29  530035642         Elizabeth Shandera
# 2  2014-11-14  530032732              Wilma Vencill
# 3  2014-11-14  530042800            Krissy Petersen
# 4  2014-11-24  530047381    Dennis & Robin McIntosh
# ..        ...        ...                        ...
# 86 2015-11-05  530016818  Stanley & Beverly Pearson
# 87 2015-11-20  530151659   Lawrence & Nicole Snyder
# 88 2016-01-25  530028050     Whiting Oil & Gas Corp
# 89 2016-03-06  530029146     Daniel & Misty Curtis
# 90 2016-07-25  530028522      David & Martha Cannon
#
#                             Buyer  \
# 0                   Preston Walls
# 1   Chauncey & Stephanie Pedersen
# 2                   Michael Mowry
# 3                     Roy Hammond
# 4         Marc & Elizabeth Taylor
# ..                            ...
# 86                Barbara Michael
# 87        Robert & Fawney Vincent
# 88                  Austin Garner
# 89           Natalie & Owen Elder
# 90             Paul & Linda Piatz
#
#                                    LEGAL DESCRIPTION   Sale Price  \
# 0   SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                        KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2   CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3            SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4    ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                ...         ...
# 86  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    175750.0
# 87                    4.954A. TRACT IN SW1/4 30-15-56    123000.0
# 88            63.398 A. TRACT IN SE CORNER 10-16-58       95000.0
# 89  LOTS 6 & 7 LESS TRACT PRAIRIE RIDGE     ESTATE...    185000.0
# 90                      19.854 ACRE TRACT IN 12-16-59    173000.0
#
#    Assessor Location
# 0            Kimball
# 1            Kimball
# 2            Kimball
# 3            Kimball
# 4            Kimball
# ..               ...
# 86        Rural Resi
# 87        Rural Resi
# 88        Rural Resi
# 89        Rural Resi
# 90        Rural Resi
#
# [91 rows x 7 columns]
#      Sale Date  Parcel ID                         Seller  \
# 0          NaT        NaN                            NaN
# 1   2017-10-12  530038722                  Carson R Sisk
# 2   2017-10-20  530034484                 Donna L Luther
# 3   2017-10-26  530042738    Rhonda Green & Roger Seeman
# 4   2017-10-27  530035642  Chauncey & Stephanie Pedersen
# ..         ...        ...                            ...
# 128 2018-12-07  530061201         Sam & Lovina Gingerich
# 129 2018-12-19  530009099        Maury D & Diane B Horst
# 130 2019-03-22  530157749         David & Joanna Hottell
# 131 2019-05-13  530029073                 Robert Mueller
# 132 2019-08-30  530017377       Darren L & Kelleigh Huff
#
#                              Buyer  \
# 0                              NaN
# 1                 Shelby L Widener
# 2       David J & Barbara A Nickel
# 3         Joshua & Bobbie J Ybarra
# 4      Monica Cajero & Efrain Soto
# ..                             ...
# 128          Tracy & Sabine Kasten
# 129           Larry & Denise Loose
# 130                      Liam Dunn
# 131  Richard R & Kelli L Patterson
# 132                 Teresa Teppert
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                                              KIMBALL         NaN
# 1                   SOUTH PARK ADDITION BLOCK 13 LOT 9     88000.0
# 2               HILLCREST FIRST ADDITION BLOCK 1 LOT 6     73500.0
# 3    SUNNYVIEW HEIGHTS ADDITION BLOCK 13 S.6' OF LO...     75000.0
# 4                    KIMBALL HEIGHTS ADDITION - LOT 13    138000.0
# ..                                                 ...         ...
# 128                1.82 ACRES IN N 1/2 NW 1/4 35-15-54     45000.0
# 129                 20.07 ACRE TRACT IN NE 1/4 5-14-54    105000.0
# 130       TRACT IN SE 1/4 OF SE 1/4 OF SW 1/W 22-13-53    125000.0
# 131                LOT 1 PRAIRIE RIDGE ESTATE 17-15-55    249000.0
# 132  11.449 ACRES IN THE SE 1/4 OF THE SW 1/4 SOUTH...    157000.0
#
#     Assessor Location
# 0                 NaN
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 128        Rural Resi
# 129        Rural Resi
# 130        Rural Resi
# 131        Rural Resi
# 132        Rural Resi
#
# [133 rows x 7 columns]
#      Sale Date  Parcel ID                       Seller  \
# 0   2015-10-19  530035847              Donald Thompson
# 1   2015-10-26  530045036              William Loring
# 2   2015-10-27  530033003  William & Winifred Petersen
# 3   2015-11-12  530017318     James & Charlotta Young
# 4   2015-11-27  530033798           Marcelino Calderon
# ..         ...        ...                          ...
# 116 2017-08-25  530010445           Lyle & Shonna Yung
# 117 2017-09-14  530151659      Robert & Fawney Vincent
# 118        NaT        NaN                          NaN
# 119        NaT        NaN                          NaN
# 120        NaT        NaN
#
#                            Buyer  \
# 0        Carolyn & Jennette Wood
# 1                    Aleta Lewis
# 2    Matthew & Rachel Merryfield
# 3           Jose & Fatima Lozoya
# 4        Daniel & Sherry Acheson
# ..                           ...
# 116     Daniel & Mercedes Arnold
# 117    Christine & Eddie Sharkey
# 118                          NaN
# 119                          NaN
# 120                          NaN
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                           KINGSWOOD FIRST ADD. LOT 1     62000.0
# 1    BURG'S ADD. BLOCK 2 ALL OF SUBLOT 1 OF  LOTS 1...     30000.0
# 2                     DOWD'S FIRST ADD. BLOCK 2 LOT 1      87500.0
# 3    PART OF THE SW 1/4 SOUTH OF THE UPRR    28-15-55      95000.0
# 4           FAIRVIEW ADD. BLOCK 4 LOTS 21-22-23 AND 24     30000.0
# ..                                                 ...         ...
# 116           PART OF S 1/2 S 1/2 6-14-55 30.012 ACRES    235000.0
# 117                4.954 ACRE TRACT IN SW 1/4 30-15-56    135000.0
# 118                                                NaN         NaN
# 119                                                NaN         NaN
# 120                                                NaN         NaN
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 116        Rural Resi
# 117        Rural Resi
# 118               NaN
# 119               NaN
# 120               NaN
#
# [121 rows x 7 columns]
#      Sale Date  Parcel ID                          Seller  \
# 0          NaT        NaN                             NaN
# 1   2018-10-16  530040824      Larry L & JoAnne M Fleagle
# 2   2018-10-18  530033429        Melvin D & Sarah E Bouse
# 3   2018-10-23  530036703              Patrick H Connelly
# 4   2018-10-26  530043416                 Lisa A Rockhold
# ..         ...        ...                             ...
# 133 2020-02-15  530010518               Trevor L Chrystal
# 134 2020-03-13  530021609      Scott E & Susan L Lockwood
# 135 2020-03-14  530029103  Douglas J & Marvel L Linthicum
# 136 2020-04-01  530018365                   Walter L Wann
# 137 2020-07-24  530050439      Dwayne A & Jonita M Groves
#
#                                   Buyer  \
# 0                                   NaN
# 1                   Christopher J Woods
# 2                        Ka'Lani O'Shea
# 3                      Mary Ann Felkins
# 4    Virginia K, Troy L & Julie E Davis
# ..                                  ...
# 133            Michael T & Renee A Geha
# 134           Dalton & Ainsley Lockwood
# 135        Trevor L & Nicole M Anderson
# 136                 Robert D Dunkin III
# 137   Bradley Ray & Nicole Lynn Hottell
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                                              KIMBALL         NaN
# 1    ORIGINAL KIMBALL ADDITION BLOCK 21 LOTS 7 THRU 12     62000.0
# 2                DOWD'S SECOND ADDITION BLOCK - LOT 14     80000.0
# 3                     LEAMINGS ADDITION BLOCK 7 LOT 1      40000.0
# 4                     YANNAYON ADDITION BLOCK 2 LOT 20     75500.0
# ..                                                 ...         ...
# 133         1.907 ACRES IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 134                           23.147 ACRES IN 36-15-57    490000.0
# 135                LOT 3 PRAIRIE RIDGE ESTATE 17-15-55    255000.0
# 136                    TRACT IN NE 1/4 NW 1/4 31-15-55     70000.0
# 137               12.415 ACRE TRACT IN NE 1/4 29-15-55    135000.0
#
#       Assessed Value Assessor Location
# 0    at time of sale               NaN
# 1              40020           Kimball
# 2             102980           Kimball
# 3              18875           Kimball
# 4              67475           Kimball
# ..               ...               ...
# 133            74345        Rural Resi
# 134           300120        Rural Resi
# 135           206040        Rural Resi
# 136            87090        Rural Resi
# 137           197340        Rural Resi
#
# [138 rows x 8 columns]
#      Sale Date  Parcel ID                        Seller  \
# 0          NaT        NaN                           NaN
# 1   2019-10-03  530042460  Kathleen P & Ricky L Chapman
# 2   2019-10-17  530033399                   Tammy Adair
# 3   2019-11-06  530036754   Howard R & Shirley J Hoberg
# 4   2019-11-07  530035448          Dan J & Cindy L Dean
# ..         ...        ...                           ...
# 170 2021-03-05  530010445               Daniel B Arnold
# 171 2021-03-25  530024640       Kathleen Atkins Trustee
# 172 2021-05-03  530005069      Garland & Megan Hamilton
# 173 2021-08-05  530010518      Michael T & Renee A Geha
# 174 2021-09-28  530016818             Barbara K Michael
#
#                                     Buyer  \
# 0                                     NaN
# 1    Paul Richard & Rebecca Ellen Burris
# 2                          Doris F Burton
# 3                David W & Debra A Gibson
# 4              Ryan M & Tiffany K Johnson
# ..                                    ...
# 170       Timothy Wayne & Dixie Lee Smith
# 171         Ryan Lukassen & Elyse Schlake
# 172                        Sara Silvanage
# 173                             Adam Geha
# 174                      Carmen M Jackman
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                                              KIMBALL         NaN
# 1            SUNNYVIEW HEIGHTS ADDITION BLOCK 11 LOT 4     92500.0
# 2    DOWD'S SECOND ADDITION BLOCK - LOT 10 AND SW 2...    147000.0
# 3    LEAMINGS ADD BLOCK 7 LOT 6 AND THE N 1/2 OF LOT 7     89500.0
# 4    HUFF'S SECOND ADDITION BLOCK 1 S 5' OF LOT 1 A...    170000.0
# ..                                                 ...         ...
# 170                   6-14-55 PART OF S1/2S1/2 6-14-55    330000.0
# 171           25-16-54 A TRACT IN THE N/2NE/4 25-16-54    265000.0
# 172           6.502 ACRE TRACT IN NE1/4NE1/4 26-13-55     122000.0
# 173            1.907 A. IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 174  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
#
#       Assessed Value Assessor Location
# 0    at time of sale               NaN
# 1              71505           Kimball
# 2             125245           Kimball
# 3              76555           Kimball
# 4             175775           Kimball
# ..               ...               ...
# 170           215195        Rural Resi
# 171           161020        Rural Resi
# 172           103510        Rural Resi
# 173            74345        Rural Resi
# 174           156655        Rural Resi
#
# [175 rows x 8 columns]
#      Sale Date  Parcel ID                        Seller  \
# 0   2016-10-13  530045583                 James Buckley
# 1   2016-10-17  530041286     Charles & Carolyn Carlson
# 2   2016-10-20  530035448  James Prince & Nancy Garrett
# 3   2016-10-24  530032546                  Claire Tritt
# 4   2016-11-05  530045273            Jennifer Dillinger
# ..         ...        ...                           ...
# 137 2018-06-15  530020696     Michael H & Karen M Isley
# 138 2018-07-06  530031094               Karla J Jenkins
# 139 2018-07-18  530151470     Jared C & Melissa L Reich
# 140 2018-08-01  530025779               Jeanne Anderson
# 141 2018-09-14  530026937              Mary Ann Felkins
#
#                                    Buyer  \
# 0                      Scott Christensen
# 1             Richard & Gloria Brookman
# 2    Patricia Biesecker & Deanna Bleyle
# 3                   Ricky & Julia Gehrig
# 4                            Rachel Rowe
# ..                                   ...
# 137                     James N Columbia
# 138                Marvin & Sandra Tabor
# 139                        Karla Jenkins
# 140                     Cheryl Delaplane
# 141            John M & Alicia I Buchart
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                            BURGS ADD. BLOCK 6 LOT 8      37000.0
# 1    SOUTH PARK ADD. BLOCK 2 ALL LOT 8 AND S1/8 OF ...    150000.0
# 2    HUFFS SECOND ADD. BLOCK 1 S. 5' OF LOT 1 AND A...    120000.0
# 3    CLARKSON ADD. BLOCK 8 S. 20' OF LOT 7 AND ALL ...     83000.0
# 4     BURG'S ADD. BLOCK 4 ALL LOT 7 AND N 15' OF LOT 8     30000.0
# ..                                                 ...         ...
# 137                         A TRACT IN SE 1/4 28-15-56    165000.0
# 138                 TRACT S OF UPRR IN SE 1/4 26-15-56    130000.0
# 139                  29.823 A TRACT IN NE 1/4 18-16-55    217500.0
# 140              TRACT IN WEST PART OF NW 1/4 32-16-55     67000.0
# 141  7.015 ACRES IN THE NE 1/4 OF THE NE 1/4 OF TH ...    180000.0
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 137        Rural Resi
# 138        Rural Resi
# 139        Rural Resi
# 140        Rural Resi
# 141        Rural Resi
#
# [142 rows x 7 columns]
#      Sale Date  Parcel ID                           Seller  \
# 0          NaT        NaN                              NaN
# 1   2020-10-01  530033429                   Ka'Lani O'Shea
# 2   2020-10-01  530036932                Chico R Fernandez
# 3   2020-10-06  530033488  Justin W & Jacqueline N Prather
# 4   2020-10-06  530039036          James & Donna Cederburg
# ..         ...        ...                              ...
# 138 2021-09-28  530016818                Barbara K Michael
# 139 2022-04-11  530015951      Sammie M & Lovina Gingerich
# 140 2022-04-28  530020041    Michael A & Clara Sue Salazar
# 141 2022-05-11  530151785            Jean A Mueller-Yanaga
# 142 2022-07-07  530023288               Central Properties
#
#                           Buyer  \
# 0                           NaN
# 1         Sharon June Pickering
# 2               Crystal Kisicki
# 3        Anthony & Linda Madrid
# 4                  Caleb Reuter
# ..                          ...
# 138            Carmen M Jackman
# 139  Sammie & Talia L Gingerich
# 140     Matthew & Crystal Brown
# 141              Daniel Glasgow
# 142         Adair Holdings, LLC
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                                              KIMBALL         NaN
# 1         DOWD'S SECOND ADD. BLOCK - LOT 14 (CARD #14)    100000.0
# 2    LEAMINGS ADD. BLOCK 9 S. 39' OF THE W. 80' OF ...     38000.0
# 3                   DOWD'S SECOND ADD. BLOCK - LOT 19     145000.0
# 4    SOUTH PARK ADD. BLOCK 16 W. 110' OF LOT 8 & W....     47900.0
# ..                                                 ...         ...
# 138  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
# 139         23.540 ACRES IN SE 1/4 S. OF UPRR 29-15-54    167000.0
# 140  TAX LOT 14 MORGAN'S SUBDIVISION IN E 1/2 OF SW...    305000.0
# 141   TRACT IN SE 1/4 AND E 1/2 NE 1/4 SW 1/4 33-15-55    190000.0
# 142            9.883 ACRE TRACT IN N 1/2 N 1/2 6-16-53    126185.0
#
#       Assessed Value Assessor Location
# 0    at time of sale               NaN
# 1             113040           Kimball
# 2              27545           Kimball
# 3             156090           Kimball
# 4              36120           Kimball
# ..               ...               ...
# 138           156655        Rural Resi
# 139           190030        Rural Resi
# 140           150090        Rural Resi
# 141            96960        Rural Resi
# 142           126185        Rural Resi
#
# [143 rows x 8 columns]

# %%
cleaned_dfs = []
for df in df_list:
    nas = df.loc[df.isna().any(axis=1), :]
    #display(nas)
    cleaned_dfs.append(df.loc[~df.isna().any(axis=1),:])
    display(df.loc[~df.isna().any(axis=1),:])
# Out:
#     Sale Date  Parcel ID                     Seller  \
# 0  2014-10-17  530041421      Robert & Denise Waite
# 1  2014-10-29  530035642         Elizabeth Shandera
# 2  2014-11-14  530032732              Wilma Vencill
# 3  2014-11-14  530042800            Krissy Petersen
# 4  2014-11-24  530047381    Dennis & Robin McIntosh
# ..        ...        ...                        ...
# 86 2015-11-05  530016818  Stanley & Beverly Pearson
# 87 2015-11-20  530151659   Lawrence & Nicole Snyder
# 88 2016-01-25  530028050     Whiting Oil & Gas Corp
# 89 2016-03-06  530029146     Daniel & Misty Curtis
# 90 2016-07-25  530028522      David & Martha Cannon
#
#                             Buyer  \
# 0                   Preston Walls
# 1   Chauncey & Stephanie Pedersen
# 2                   Michael Mowry
# 3                     Roy Hammond
# 4         Marc & Elizabeth Taylor
# ..                            ...
# 86                Barbara Michael
# 87        Robert & Fawney Vincent
# 88                  Austin Garner
# 89           Natalie & Owen Elder
# 90             Paul & Linda Piatz
#
#                                    LEGAL DESCRIPTION   Sale Price  \
# 0   SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                        KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2   CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3            SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4    ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                ...         ...
# 86  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    175750.0
# 87                    4.954A. TRACT IN SW1/4 30-15-56    123000.0
# 88            63.398 A. TRACT IN SE CORNER 10-16-58       95000.0
# 89  LOTS 6 & 7 LESS TRACT PRAIRIE RIDGE     ESTATE...    185000.0
# 90                      19.854 ACRE TRACT IN 12-16-59    173000.0
#
#    Assessor Location
# 0            Kimball
# 1            Kimball
# 2            Kimball
# 3            Kimball
# 4            Kimball
# ..               ...
# 86        Rural Resi
# 87        Rural Resi
# 88        Rural Resi
# 89        Rural Resi
# 90        Rural Resi
#
# [88 rows x 7 columns]
#      Sale Date  Parcel ID                         Seller  \
# 1   2017-10-12  530038722                  Carson R Sisk
# 2   2017-10-20  530034484                 Donna L Luther
# 3   2017-10-26  530042738    Rhonda Green & Roger Seeman
# 4   2017-10-27  530035642  Chauncey & Stephanie Pedersen
# 5   2017-10-27  530034735                 Irene J Wallin
# ..         ...        ...                            ...
# 128 2018-12-07  530061201         Sam & Lovina Gingerich
# 129 2018-12-19  530009099        Maury D & Diane B Horst
# 130 2019-03-22  530157749         David & Joanna Hottell
# 131 2019-05-13  530029073                 Robert Mueller
# 132 2019-08-30  530017377       Darren L & Kelleigh Huff
#
#                              Buyer  \
# 1                 Shelby L Widener
# 2       David J & Barbara A Nickel
# 3         Joshua & Bobbie J Ybarra
# 4      Monica Cajero & Efrain Soto
# 5     Bernardo & Mercedes Quinones
# ..                             ...
# 128          Tracy & Sabine Kasten
# 129           Larry & Denise Loose
# 130                      Liam Dunn
# 131  Richard R & Kelli L Patterson
# 132                 Teresa Teppert
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1                   SOUTH PARK ADDITION BLOCK 13 LOT 9     88000.0
# 2               HILLCREST FIRST ADDITION BLOCK 1 LOT 6     73500.0
# 3    SUNNYVIEW HEIGHTS ADDITION BLOCK 13 S.6' OF LO...     75000.0
# 4                    KIMBALL HEIGHTS ADDITION - LOT 13    138000.0
# 5              HILLCREST SECOND ADDITION BLOCK 2 LOT 4     55000.0
# ..                                                 ...         ...
# 128                1.82 ACRES IN N 1/2 NW 1/4 35-15-54     45000.0
# 129                 20.07 ACRE TRACT IN NE 1/4 5-14-54    105000.0
# 130       TRACT IN SE 1/4 OF SE 1/4 OF SW 1/W 22-13-53    125000.0
# 131                LOT 1 PRAIRIE RIDGE ESTATE 17-15-55    249000.0
# 132  11.449 ACRES IN THE SE 1/4 OF THE SW 1/4 SOUTH...    157000.0
#
#     Assessor Location
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# 5             Kimball
# ..                ...
# 128        Rural Resi
# 129        Rural Resi
# 130        Rural Resi
# 131        Rural Resi
# 132        Rural Resi
#
# [125 rows x 7 columns]
#      Sale Date  Parcel ID                       Seller  \
# 0   2015-10-19  530035847              Donald Thompson
# 1   2015-10-26  530045036              William Loring
# 2   2015-10-27  530033003  William & Winifred Petersen
# 3   2015-11-12  530017318     James & Charlotta Young
# 4   2015-11-27  530033798           Marcelino Calderon
# ..         ...        ...                          ...
# 113 2017-04-24  530009285   Monica & Magdaleno Cajero
# 114 2017-06-16  530020173      Kristi & Ronald Cortney
# 115 2017-07-12  530020041                Jason Hottell
# 116 2017-08-25  530010445           Lyle & Shonna Yung
# 117 2017-09-14  530151659      Robert & Fawney Vincent
#
#                            Buyer  \
# 0        Carolyn & Jennette Wood
# 1                    Aleta Lewis
# 2    Matthew & Rachel Merryfield
# 3           Jose & Fatima Lozoya
# 4        Daniel & Sherry Acheson
# ..                           ...
# 113                 Donald Weeks
# 114         Toni & Edward Barnes
# 115              Robin Whitehead
# 116     Daniel & Mercedes Arnold
# 117    Christine & Eddie Sharkey
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                           KINGSWOOD FIRST ADD. LOT 1     62000.0
# 1    BURG'S ADD. BLOCK 2 ALL OF SUBLOT 1 OF  LOTS 1...     30000.0
# 2                     DOWD'S FIRST ADD. BLOCK 2 LOT 1      87500.0
# 3    PART OF THE SW 1/4 SOUTH OF THE UPRR    28-15-55      95000.0
# 4           FAIRVIEW ADD. BLOCK 4 LOTS 21-22-23 AND 24     30000.0
# ..                                                 ...         ...
# 113   TRACT IN E 1/2 NE 1/4 OF 10-14-54 (26.849 ACRES)    135000.0
# 114  TAX LOT 8 PART OF SE 1/4 OF THE NW 1/4 & NE 1/...    150499.0
# 115  TAX LOT 14 MORGANS SUBDIVISION IN E 1/2 OF SW ...    187000.0
# 116           PART OF S 1/2 S 1/2 6-14-55 30.012 ACRES    235000.0
# 117                4.954 ACRE TRACT IN SW 1/4 30-15-56    135000.0
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 113        Rural Resi
# 114        Rural Resi
# 115        Rural Resi
# 116        Rural Resi
# 117        Rural Resi
#
# [112 rows x 7 columns]
#      Sale Date  Parcel ID                            Seller  \
# 1   2018-10-16  530040824        Larry L & JoAnne M Fleagle
# 2   2018-10-18  530033429          Melvin D & Sarah E Bouse
# 3   2018-10-23  530036703                Patrick H Connelly
# 4   2018-10-26  530043416                   Lisa A Rockhold
# 5   2018-12-14  530035626  Kenneth H & Cynthia Stone Hunter
# ..         ...        ...                               ...
# 133 2020-02-15  530010518                 Trevor L Chrystal
# 134 2020-03-13  530021609        Scott E & Susan L Lockwood
# 135 2020-03-14  530029103    Douglas J & Marvel L Linthicum
# 136 2020-04-01  530018365                     Walter L Wann
# 137 2020-07-24  530050439        Dwayne A & Jonita M Groves
#
#                                   Buyer  \
# 1                   Christopher J Woods
# 2                        Ka'Lani O'Shea
# 3                      Mary Ann Felkins
# 4    Virginia K, Troy L & Julie E Davis
# 5               Ty M & Jessica S Gibson
# ..                                  ...
# 133            Michael T & Renee A Geha
# 134           Dalton & Ainsley Lockwood
# 135        Trevor L & Nicole M Anderson
# 136                 Robert D Dunkin III
# 137   Bradley Ray & Nicole Lynn Hottell
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1    ORIGINAL KIMBALL ADDITION BLOCK 21 LOTS 7 THRU 12     62000.0
# 2                DOWD'S SECOND ADDITION BLOCK - LOT 14     80000.0
# 3                     LEAMINGS ADDITION BLOCK 7 LOT 1      40000.0
# 4                     YANNAYON ADDITION BLOCK 2 LOT 20     75500.0
# 5    KIMBALL HEIGHTS ADDITION N. 23' OF LOT 9 AND A...    189000.0
# ..                                                 ...         ...
# 133         1.907 ACRES IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 134                           23.147 ACRES IN 36-15-57    490000.0
# 135                LOT 3 PRAIRIE RIDGE ESTATE 17-15-55    255000.0
# 136                    TRACT IN NE 1/4 NW 1/4 31-15-55     70000.0
# 137               12.415 ACRE TRACT IN NE 1/4 29-15-55    135000.0
#
#     Assessed Value Assessor Location
# 1            40020           Kimball
# 2           102980           Kimball
# 3            18875           Kimball
# 4            67475           Kimball
# 5           171090           Kimball
# ..             ...               ...
# 133          74345        Rural Resi
# 134         300120        Rural Resi
# 135         206040        Rural Resi
# 136          87090        Rural Resi
# 137         197340        Rural Resi
#
# [129 rows x 8 columns]
#      Sale Date  Parcel ID                        Seller  \
# 1   2019-10-03  530042460  Kathleen P & Ricky L Chapman
# 2   2019-10-17  530033399                   Tammy Adair
# 3   2019-11-06  530036754   Howard R & Shirley J Hoberg
# 4   2019-11-07  530035448          Dan J & Cindy L Dean
# 5   2019-11-11  530038803              Diana K Fiehtner
# ..         ...        ...                           ...
# 170 2021-03-05  530010445               Daniel B Arnold
# 171 2021-03-25  530024640       Kathleen Atkins Trustee
# 172 2021-05-03  530005069      Garland & Megan Hamilton
# 173 2021-08-05  530010518      Michael T & Renee A Geha
# 174 2021-09-28  530016818             Barbara K Michael
#
#                                     Buyer  \
# 1    Paul Richard & Rebecca Ellen Burris
# 2                          Doris F Burton
# 3                David W & Debra A Gibson
# 4              Ryan M & Tiffany K Johnson
# 5                  Frank & Norma Stauffer
# ..                                    ...
# 170       Timothy Wayne & Dixie Lee Smith
# 171         Ryan Lukassen & Elyse Schlake
# 172                        Sara Silvanage
# 173                             Adam Geha
# 174                      Carmen M Jackman
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1            SUNNYVIEW HEIGHTS ADDITION BLOCK 11 LOT 4     92500.0
# 2    DOWD'S SECOND ADDITION BLOCK - LOT 10 AND SW 2...    147000.0
# 3    LEAMINGS ADD BLOCK 7 LOT 6 AND THE N 1/2 OF LOT 7     89500.0
# 4    HUFF'S SECOND ADDITION BLOCK 1 S 5' OF LOT 1 A...    170000.0
# 5    SOUTH PARK ADDITION BLOCK 14 W 80' OF LOTS 1-3...     60000.0
# ..                                                 ...         ...
# 170                   6-14-55 PART OF S1/2S1/2 6-14-55    330000.0
# 171           25-16-54 A TRACT IN THE N/2NE/4 25-16-54    265000.0
# 172           6.502 ACRE TRACT IN NE1/4NE1/4 26-13-55     122000.0
# 173            1.907 A. IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 174  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
#
#     Assessed Value Assessor Location
# 1            71505           Kimball
# 2           125245           Kimball
# 3            76555           Kimball
# 4           175775           Kimball
# 5            53015           Kimball
# ..             ...               ...
# 170         215195        Rural Resi
# 171         161020        Rural Resi
# 172         103510        Rural Resi
# 173          74345        Rural Resi
# 174         156655        Rural Resi
#
# [167 rows x 8 columns]
#      Sale Date  Parcel ID                        Seller  \
# 0   2016-10-13  530045583                 James Buckley
# 1   2016-10-17  530041286     Charles & Carolyn Carlson
# 2   2016-10-20  530035448  James Prince & Nancy Garrett
# 3   2016-10-24  530032546                  Claire Tritt
# 4   2016-11-05  530045273            Jennifer Dillinger
# ..         ...        ...                           ...
# 137 2018-06-15  530020696     Michael H & Karen M Isley
# 138 2018-07-06  530031094               Karla J Jenkins
# 139 2018-07-18  530151470     Jared C & Melissa L Reich
# 140 2018-08-01  530025779               Jeanne Anderson
# 141 2018-09-14  530026937              Mary Ann Felkins
#
#                                    Buyer  \
# 0                      Scott Christensen
# 1             Richard & Gloria Brookman
# 2    Patricia Biesecker & Deanna Bleyle
# 3                   Ricky & Julia Gehrig
# 4                            Rachel Rowe
# ..                                   ...
# 137                     James N Columbia
# 138                Marvin & Sandra Tabor
# 139                        Karla Jenkins
# 140                     Cheryl Delaplane
# 141            John M & Alicia I Buchart
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                            BURGS ADD. BLOCK 6 LOT 8      37000.0
# 1    SOUTH PARK ADD. BLOCK 2 ALL LOT 8 AND S1/8 OF ...    150000.0
# 2    HUFFS SECOND ADD. BLOCK 1 S. 5' OF LOT 1 AND A...    120000.0
# 3    CLARKSON ADD. BLOCK 8 S. 20' OF LOT 7 AND ALL ...     83000.0
# 4     BURG'S ADD. BLOCK 4 ALL LOT 7 AND N 15' OF LOT 8     30000.0
# ..                                                 ...         ...
# 137                         A TRACT IN SE 1/4 28-15-56    165000.0
# 138                 TRACT S OF UPRR IN SE 1/4 26-15-56    130000.0
# 139                  29.823 A TRACT IN NE 1/4 18-16-55    217500.0
# 140              TRACT IN WEST PART OF NW 1/4 32-16-55     67000.0
# 141  7.015 ACRES IN THE NE 1/4 OF THE NE 1/4 OF TH ...    180000.0
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 137        Rural Resi
# 138        Rural Resi
# 139        Rural Resi
# 140        Rural Resi
# 141        Rural Resi
#
# [136 rows x 7 columns]
#      Sale Date  Parcel ID                           Seller  \
# 1   2020-10-01  530033429                   Ka'Lani O'Shea
# 2   2020-10-01  530036932                Chico R Fernandez
# 3   2020-10-06  530033488  Justin W & Jacqueline N Prather
# 4   2020-10-06  530039036          James & Donna Cederburg
# 5   2020-10-20  530042959                    Carol L Meyer
# ..         ...        ...                              ...
# 138 2021-09-28  530016818                Barbara K Michael
# 139 2022-04-11  530015951      Sammie M & Lovina Gingerich
# 140 2022-04-28  530020041    Michael A & Clara Sue Salazar
# 141 2022-05-11  530151785            Jean A Mueller-Yanaga
# 142 2022-07-07  530023288               Central Properties
#
#                           Buyer  \
# 1         Sharon June Pickering
# 2               Crystal Kisicki
# 3        Anthony & Linda Madrid
# 4                  Caleb Reuter
# 5                  Danny E Yung
# ..                          ...
# 138            Carmen M Jackman
# 139  Sammie & Talia L Gingerich
# 140     Matthew & Crystal Brown
# 141              Daniel Glasgow
# 142         Adair Holdings, LLC
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1         DOWD'S SECOND ADD. BLOCK - LOT 14 (CARD #14)    100000.0
# 2    LEAMINGS ADD. BLOCK 9 S. 39' OF THE W. 80' OF ...     38000.0
# 3                   DOWD'S SECOND ADD. BLOCK - LOT 19     145000.0
# 4    SOUTH PARK ADD. BLOCK 16 W. 110' OF LOT 8 & W....     47900.0
# 5    SUNNYVIEW HEIGHTS ADD. BLOCK 14 N. 5' OF LOT 1...     71100.0
# ..                                                 ...         ...
# 138  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
# 139         23.540 ACRES IN SE 1/4 S. OF UPRR 29-15-54    167000.0
# 140  TAX LOT 14 MORGAN'S SUBDIVISION IN E 1/2 OF SW...    305000.0
# 141   TRACT IN SE 1/4 AND E 1/2 NE 1/4 SW 1/4 33-15-55    190000.0
# 142            9.883 ACRE TRACT IN N 1/2 N 1/2 6-16-53    126185.0
#
#     Assessed Value Assessor Location
# 1           113040           Kimball
# 2            27545           Kimball
# 3           156090           Kimball
# 4            36120           Kimball
# 5            82945           Kimball
# ..             ...               ...
# 138         156655        Rural Resi
# 139         190030        Rural Resi
# 140         150090        Rural Resi
# 141          96960        Rural Resi
# 142         126185        Rural Resi
#
# [137 rows x 8 columns]

# %%
for df in cleaned_dfs:
    display(df)
# Out:
#     Sale Date  Parcel ID                     Seller  \
# 0  2014-10-17  530041421      Robert & Denise Waite
# 1  2014-10-29  530035642         Elizabeth Shandera
# 2  2014-11-14  530032732              Wilma Vencill
# 3  2014-11-14  530042800            Krissy Petersen
# 4  2014-11-24  530047381    Dennis & Robin McIntosh
# ..        ...        ...                        ...
# 86 2015-11-05  530016818  Stanley & Beverly Pearson
# 87 2015-11-20  530151659   Lawrence & Nicole Snyder
# 88 2016-01-25  530028050     Whiting Oil & Gas Corp
# 89 2016-03-06  530029146     Daniel & Misty Curtis
# 90 2016-07-25  530028522      David & Martha Cannon
#
#                             Buyer  \
# 0                   Preston Walls
# 1   Chauncey & Stephanie Pedersen
# 2                   Michael Mowry
# 3                     Roy Hammond
# 4         Marc & Elizabeth Taylor
# ..                            ...
# 86                Barbara Michael
# 87        Robert & Fawney Vincent
# 88                  Austin Garner
# 89           Natalie & Owen Elder
# 90             Paul & Linda Piatz
#
#                                    LEGAL DESCRIPTION   Sale Price  \
# 0   SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                        KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2   CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3            SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4    ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                ...         ...
# 86  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    175750.0
# 87                    4.954A. TRACT IN SW1/4 30-15-56    123000.0
# 88            63.398 A. TRACT IN SE CORNER 10-16-58       95000.0
# 89  LOTS 6 & 7 LESS TRACT PRAIRIE RIDGE     ESTATE...    185000.0
# 90                      19.854 ACRE TRACT IN 12-16-59    173000.0
#
#    Assessor Location
# 0            Kimball
# 1            Kimball
# 2            Kimball
# 3            Kimball
# 4            Kimball
# ..               ...
# 86        Rural Resi
# 87        Rural Resi
# 88        Rural Resi
# 89        Rural Resi
# 90        Rural Resi
#
# [88 rows x 7 columns]
#      Sale Date  Parcel ID                         Seller  \
# 1   2017-10-12  530038722                  Carson R Sisk
# 2   2017-10-20  530034484                 Donna L Luther
# 3   2017-10-26  530042738    Rhonda Green & Roger Seeman
# 4   2017-10-27  530035642  Chauncey & Stephanie Pedersen
# 5   2017-10-27  530034735                 Irene J Wallin
# ..         ...        ...                            ...
# 128 2018-12-07  530061201         Sam & Lovina Gingerich
# 129 2018-12-19  530009099        Maury D & Diane B Horst
# 130 2019-03-22  530157749         David & Joanna Hottell
# 131 2019-05-13  530029073                 Robert Mueller
# 132 2019-08-30  530017377       Darren L & Kelleigh Huff
#
#                              Buyer  \
# 1                 Shelby L Widener
# 2       David J & Barbara A Nickel
# 3         Joshua & Bobbie J Ybarra
# 4      Monica Cajero & Efrain Soto
# 5     Bernardo & Mercedes Quinones
# ..                             ...
# 128          Tracy & Sabine Kasten
# 129           Larry & Denise Loose
# 130                      Liam Dunn
# 131  Richard R & Kelli L Patterson
# 132                 Teresa Teppert
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1                   SOUTH PARK ADDITION BLOCK 13 LOT 9     88000.0
# 2               HILLCREST FIRST ADDITION BLOCK 1 LOT 6     73500.0
# 3    SUNNYVIEW HEIGHTS ADDITION BLOCK 13 S.6' OF LO...     75000.0
# 4                    KIMBALL HEIGHTS ADDITION - LOT 13    138000.0
# 5              HILLCREST SECOND ADDITION BLOCK 2 LOT 4     55000.0
# ..                                                 ...         ...
# 128                1.82 ACRES IN N 1/2 NW 1/4 35-15-54     45000.0
# 129                 20.07 ACRE TRACT IN NE 1/4 5-14-54    105000.0
# 130       TRACT IN SE 1/4 OF SE 1/4 OF SW 1/W 22-13-53    125000.0
# 131                LOT 1 PRAIRIE RIDGE ESTATE 17-15-55    249000.0
# 132  11.449 ACRES IN THE SE 1/4 OF THE SW 1/4 SOUTH...    157000.0
#
#     Assessor Location
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# 5             Kimball
# ..                ...
# 128        Rural Resi
# 129        Rural Resi
# 130        Rural Resi
# 131        Rural Resi
# 132        Rural Resi
#
# [125 rows x 7 columns]
#      Sale Date  Parcel ID                       Seller  \
# 0   2015-10-19  530035847              Donald Thompson
# 1   2015-10-26  530045036              William Loring
# 2   2015-10-27  530033003  William & Winifred Petersen
# 3   2015-11-12  530017318     James & Charlotta Young
# 4   2015-11-27  530033798           Marcelino Calderon
# ..         ...        ...                          ...
# 113 2017-04-24  530009285   Monica & Magdaleno Cajero
# 114 2017-06-16  530020173      Kristi & Ronald Cortney
# 115 2017-07-12  530020041                Jason Hottell
# 116 2017-08-25  530010445           Lyle & Shonna Yung
# 117 2017-09-14  530151659      Robert & Fawney Vincent
#
#                            Buyer  \
# 0        Carolyn & Jennette Wood
# 1                    Aleta Lewis
# 2    Matthew & Rachel Merryfield
# 3           Jose & Fatima Lozoya
# 4        Daniel & Sherry Acheson
# ..                           ...
# 113                 Donald Weeks
# 114         Toni & Edward Barnes
# 115              Robin Whitehead
# 116     Daniel & Mercedes Arnold
# 117    Christine & Eddie Sharkey
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                           KINGSWOOD FIRST ADD. LOT 1     62000.0
# 1    BURG'S ADD. BLOCK 2 ALL OF SUBLOT 1 OF  LOTS 1...     30000.0
# 2                     DOWD'S FIRST ADD. BLOCK 2 LOT 1      87500.0
# 3    PART OF THE SW 1/4 SOUTH OF THE UPRR    28-15-55      95000.0
# 4           FAIRVIEW ADD. BLOCK 4 LOTS 21-22-23 AND 24     30000.0
# ..                                                 ...         ...
# 113   TRACT IN E 1/2 NE 1/4 OF 10-14-54 (26.849 ACRES)    135000.0
# 114  TAX LOT 8 PART OF SE 1/4 OF THE NW 1/4 & NE 1/...    150499.0
# 115  TAX LOT 14 MORGANS SUBDIVISION IN E 1/2 OF SW ...    187000.0
# 116           PART OF S 1/2 S 1/2 6-14-55 30.012 ACRES    235000.0
# 117                4.954 ACRE TRACT IN SW 1/4 30-15-56    135000.0
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 113        Rural Resi
# 114        Rural Resi
# 115        Rural Resi
# 116        Rural Resi
# 117        Rural Resi
#
# [112 rows x 7 columns]
#      Sale Date  Parcel ID                            Seller  \
# 1   2018-10-16  530040824        Larry L & JoAnne M Fleagle
# 2   2018-10-18  530033429          Melvin D & Sarah E Bouse
# 3   2018-10-23  530036703                Patrick H Connelly
# 4   2018-10-26  530043416                   Lisa A Rockhold
# 5   2018-12-14  530035626  Kenneth H & Cynthia Stone Hunter
# ..         ...        ...                               ...
# 133 2020-02-15  530010518                 Trevor L Chrystal
# 134 2020-03-13  530021609        Scott E & Susan L Lockwood
# 135 2020-03-14  530029103    Douglas J & Marvel L Linthicum
# 136 2020-04-01  530018365                     Walter L Wann
# 137 2020-07-24  530050439        Dwayne A & Jonita M Groves
#
#                                   Buyer  \
# 1                   Christopher J Woods
# 2                        Ka'Lani O'Shea
# 3                      Mary Ann Felkins
# 4    Virginia K, Troy L & Julie E Davis
# 5               Ty M & Jessica S Gibson
# ..                                  ...
# 133            Michael T & Renee A Geha
# 134           Dalton & Ainsley Lockwood
# 135        Trevor L & Nicole M Anderson
# 136                 Robert D Dunkin III
# 137   Bradley Ray & Nicole Lynn Hottell
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1    ORIGINAL KIMBALL ADDITION BLOCK 21 LOTS 7 THRU 12     62000.0
# 2                DOWD'S SECOND ADDITION BLOCK - LOT 14     80000.0
# 3                     LEAMINGS ADDITION BLOCK 7 LOT 1      40000.0
# 4                     YANNAYON ADDITION BLOCK 2 LOT 20     75500.0
# 5    KIMBALL HEIGHTS ADDITION N. 23' OF LOT 9 AND A...    189000.0
# ..                                                 ...         ...
# 133         1.907 ACRES IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 134                           23.147 ACRES IN 36-15-57    490000.0
# 135                LOT 3 PRAIRIE RIDGE ESTATE 17-15-55    255000.0
# 136                    TRACT IN NE 1/4 NW 1/4 31-15-55     70000.0
# 137               12.415 ACRE TRACT IN NE 1/4 29-15-55    135000.0
#
#     Assessed Value Assessor Location
# 1            40020           Kimball
# 2           102980           Kimball
# 3            18875           Kimball
# 4            67475           Kimball
# 5           171090           Kimball
# ..             ...               ...
# 133          74345        Rural Resi
# 134         300120        Rural Resi
# 135         206040        Rural Resi
# 136          87090        Rural Resi
# 137         197340        Rural Resi
#
# [129 rows x 8 columns]
#      Sale Date  Parcel ID                        Seller  \
# 1   2019-10-03  530042460  Kathleen P & Ricky L Chapman
# 2   2019-10-17  530033399                   Tammy Adair
# 3   2019-11-06  530036754   Howard R & Shirley J Hoberg
# 4   2019-11-07  530035448          Dan J & Cindy L Dean
# 5   2019-11-11  530038803              Diana K Fiehtner
# ..         ...        ...                           ...
# 170 2021-03-05  530010445               Daniel B Arnold
# 171 2021-03-25  530024640       Kathleen Atkins Trustee
# 172 2021-05-03  530005069      Garland & Megan Hamilton
# 173 2021-08-05  530010518      Michael T & Renee A Geha
# 174 2021-09-28  530016818             Barbara K Michael
#
#                                     Buyer  \
# 1    Paul Richard & Rebecca Ellen Burris
# 2                          Doris F Burton
# 3                David W & Debra A Gibson
# 4              Ryan M & Tiffany K Johnson
# 5                  Frank & Norma Stauffer
# ..                                    ...
# 170       Timothy Wayne & Dixie Lee Smith
# 171         Ryan Lukassen & Elyse Schlake
# 172                        Sara Silvanage
# 173                             Adam Geha
# 174                      Carmen M Jackman
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1            SUNNYVIEW HEIGHTS ADDITION BLOCK 11 LOT 4     92500.0
# 2    DOWD'S SECOND ADDITION BLOCK - LOT 10 AND SW 2...    147000.0
# 3    LEAMINGS ADD BLOCK 7 LOT 6 AND THE N 1/2 OF LOT 7     89500.0
# 4    HUFF'S SECOND ADDITION BLOCK 1 S 5' OF LOT 1 A...    170000.0
# 5    SOUTH PARK ADDITION BLOCK 14 W 80' OF LOTS 1-3...     60000.0
# ..                                                 ...         ...
# 170                   6-14-55 PART OF S1/2S1/2 6-14-55    330000.0
# 171           25-16-54 A TRACT IN THE N/2NE/4 25-16-54    265000.0
# 172           6.502 ACRE TRACT IN NE1/4NE1/4 26-13-55     122000.0
# 173            1.907 A. IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 174  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
#
#     Assessed Value Assessor Location
# 1            71505           Kimball
# 2           125245           Kimball
# 3            76555           Kimball
# 4           175775           Kimball
# 5            53015           Kimball
# ..             ...               ...
# 170         215195        Rural Resi
# 171         161020        Rural Resi
# 172         103510        Rural Resi
# 173          74345        Rural Resi
# 174         156655        Rural Resi
#
# [167 rows x 8 columns]
#      Sale Date  Parcel ID                        Seller  \
# 0   2016-10-13  530045583                 James Buckley
# 1   2016-10-17  530041286     Charles & Carolyn Carlson
# 2   2016-10-20  530035448  James Prince & Nancy Garrett
# 3   2016-10-24  530032546                  Claire Tritt
# 4   2016-11-05  530045273            Jennifer Dillinger
# ..         ...        ...                           ...
# 137 2018-06-15  530020696     Michael H & Karen M Isley
# 138 2018-07-06  530031094               Karla J Jenkins
# 139 2018-07-18  530151470     Jared C & Melissa L Reich
# 140 2018-08-01  530025779               Jeanne Anderson
# 141 2018-09-14  530026937              Mary Ann Felkins
#
#                                    Buyer  \
# 0                      Scott Christensen
# 1             Richard & Gloria Brookman
# 2    Patricia Biesecker & Deanna Bleyle
# 3                   Ricky & Julia Gehrig
# 4                            Rachel Rowe
# ..                                   ...
# 137                     James N Columbia
# 138                Marvin & Sandra Tabor
# 139                        Karla Jenkins
# 140                     Cheryl Delaplane
# 141            John M & Alicia I Buchart
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0                            BURGS ADD. BLOCK 6 LOT 8      37000.0
# 1    SOUTH PARK ADD. BLOCK 2 ALL LOT 8 AND S1/8 OF ...    150000.0
# 2    HUFFS SECOND ADD. BLOCK 1 S. 5' OF LOT 1 AND A...    120000.0
# 3    CLARKSON ADD. BLOCK 8 S. 20' OF LOT 7 AND ALL ...     83000.0
# 4     BURG'S ADD. BLOCK 4 ALL LOT 7 AND N 15' OF LOT 8     30000.0
# ..                                                 ...         ...
# 137                         A TRACT IN SE 1/4 28-15-56    165000.0
# 138                 TRACT S OF UPRR IN SE 1/4 26-15-56    130000.0
# 139                  29.823 A TRACT IN NE 1/4 18-16-55    217500.0
# 140              TRACT IN WEST PART OF NW 1/4 32-16-55     67000.0
# 141  7.015 ACRES IN THE NE 1/4 OF THE NE 1/4 OF TH ...    180000.0
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 137        Rural Resi
# 138        Rural Resi
# 139        Rural Resi
# 140        Rural Resi
# 141        Rural Resi
#
# [136 rows x 7 columns]
#      Sale Date  Parcel ID                           Seller  \
# 1   2020-10-01  530033429                   Ka'Lani O'Shea
# 2   2020-10-01  530036932                Chico R Fernandez
# 3   2020-10-06  530033488  Justin W & Jacqueline N Prather
# 4   2020-10-06  530039036          James & Donna Cederburg
# 5   2020-10-20  530042959                    Carol L Meyer
# ..         ...        ...                              ...
# 138 2021-09-28  530016818                Barbara K Michael
# 139 2022-04-11  530015951      Sammie M & Lovina Gingerich
# 140 2022-04-28  530020041    Michael A & Clara Sue Salazar
# 141 2022-05-11  530151785            Jean A Mueller-Yanaga
# 142 2022-07-07  530023288               Central Properties
#
#                           Buyer  \
# 1         Sharon June Pickering
# 2               Crystal Kisicki
# 3        Anthony & Linda Madrid
# 4                  Caleb Reuter
# 5                  Danny E Yung
# ..                          ...
# 138            Carmen M Jackman
# 139  Sammie & Talia L Gingerich
# 140     Matthew & Crystal Brown
# 141              Daniel Glasgow
# 142         Adair Holdings, LLC
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 1         DOWD'S SECOND ADD. BLOCK - LOT 14 (CARD #14)    100000.0
# 2    LEAMINGS ADD. BLOCK 9 S. 39' OF THE W. 80' OF ...     38000.0
# 3                   DOWD'S SECOND ADD. BLOCK - LOT 19     145000.0
# 4    SOUTH PARK ADD. BLOCK 16 W. 110' OF LOT 8 & W....     47900.0
# 5    SUNNYVIEW HEIGHTS ADD. BLOCK 14 N. 5' OF LOT 1...     71100.0
# ..                                                 ...         ...
# 138  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
# 139         23.540 ACRES IN SE 1/4 S. OF UPRR 29-15-54    167000.0
# 140  TAX LOT 14 MORGAN'S SUBDIVISION IN E 1/2 OF SW...    305000.0
# 141   TRACT IN SE 1/4 AND E 1/2 NE 1/4 SW 1/4 33-15-55    190000.0
# 142            9.883 ACRE TRACT IN N 1/2 N 1/2 6-16-53    126185.0
#
#     Assessed Value Assessor Location
# 1           113040           Kimball
# 2            27545           Kimball
# 3           156090           Kimball
# 4            36120           Kimball
# 5            82945           Kimball
# ..             ...               ...
# 138         156655        Rural Resi
# 139         190030        Rural Resi
# 140         150090        Rural Resi
# 141          96960        Rural Resi
# 142         126185        Rural Resi
#
# [137 rows x 8 columns]

# %%
merged_df = pd.DataFrame()

for df in cleaned_dfs:
    merged_df = pd.concat([merged_df, df], ignore_index=True)
    display(merged_df)
# Out:
#     Sale Date  Parcel ID                     Seller  \
# 0  2014-10-17  530041421      Robert & Denise Waite
# 1  2014-10-29  530035642         Elizabeth Shandera
# 2  2014-11-14  530032732              Wilma Vencill
# 3  2014-11-14  530042800            Krissy Petersen
# 4  2014-11-24  530047381    Dennis & Robin McIntosh
# ..        ...        ...                        ...
# 83 2015-11-05  530016818  Stanley & Beverly Pearson
# 84 2015-11-20  530151659   Lawrence & Nicole Snyder
# 85 2016-01-25  530028050     Whiting Oil & Gas Corp
# 86 2016-03-06  530029146     Daniel & Misty Curtis
# 87 2016-07-25  530028522      David & Martha Cannon
#
#                             Buyer  \
# 0                   Preston Walls
# 1   Chauncey & Stephanie Pedersen
# 2                   Michael Mowry
# 3                     Roy Hammond
# 4         Marc & Elizabeth Taylor
# ..                            ...
# 83                Barbara Michael
# 84        Robert & Fawney Vincent
# 85                  Austin Garner
# 86           Natalie & Owen Elder
# 87             Paul & Linda Piatz
#
#                                    LEGAL DESCRIPTION   Sale Price  \
# 0   SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                        KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2   CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3            SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4    ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                ...         ...
# 83  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    175750.0
# 84                    4.954A. TRACT IN SW1/4 30-15-56    123000.0
# 85            63.398 A. TRACT IN SE CORNER 10-16-58       95000.0
# 86  LOTS 6 & 7 LESS TRACT PRAIRIE RIDGE     ESTATE...    185000.0
# 87                      19.854 ACRE TRACT IN 12-16-59    173000.0
#
#    Assessor Location
# 0            Kimball
# 1            Kimball
# 2            Kimball
# 3            Kimball
# 4            Kimball
# ..               ...
# 83        Rural Resi
# 84        Rural Resi
# 85        Rural Resi
# 86        Rural Resi
# 87        Rural Resi
#
# [88 rows x 7 columns]
#      Sale Date  Parcel ID                    Seller  \
# 0   2014-10-17  530041421     Robert & Denise Waite
# 1   2014-10-29  530035642        Elizabeth Shandera
# 2   2014-11-14  530032732             Wilma Vencill
# 3   2014-11-14  530042800           Krissy Petersen
# 4   2014-11-24  530047381   Dennis & Robin McIntosh
# ..         ...        ...                       ...
# 208 2018-12-07  530061201    Sam & Lovina Gingerich
# 209 2018-12-19  530009099   Maury D & Diane B Horst
# 210 2019-03-22  530157749    David & Joanna Hottell
# 211 2019-05-13  530029073            Robert Mueller
# 212 2019-08-30  530017377  Darren L & Kelleigh Huff
#
#                              Buyer  \
# 0                    Preston Walls
# 1    Chauncey & Stephanie Pedersen
# 2                    Michael Mowry
# 3                      Roy Hammond
# 4          Marc & Elizabeth Taylor
# ..                             ...
# 208          Tracy & Sabine Kasten
# 209           Larry & Denise Loose
# 210                      Liam Dunn
# 211  Richard R & Kelli L Patterson
# 212                 Teresa Teppert
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0    SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                         KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2    CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3             SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4     ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                 ...         ...
# 208                1.82 ACRES IN N 1/2 NW 1/4 35-15-54     45000.0
# 209                 20.07 ACRE TRACT IN NE 1/4 5-14-54    105000.0
# 210       TRACT IN SE 1/4 OF SE 1/4 OF SW 1/W 22-13-53    125000.0
# 211                LOT 1 PRAIRIE RIDGE ESTATE 17-15-55    249000.0
# 212  11.449 ACRES IN THE SE 1/4 OF THE SW 1/4 SOUTH...    157000.0
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 208        Rural Resi
# 209        Rural Resi
# 210        Rural Resi
# 211        Rural Resi
# 212        Rural Resi
#
# [213 rows x 7 columns]
#      Sale Date  Parcel ID                      Seller  \
# 0   2014-10-17  530041421       Robert & Denise Waite
# 1   2014-10-29  530035642          Elizabeth Shandera
# 2   2014-11-14  530032732               Wilma Vencill
# 3   2014-11-14  530042800             Krissy Petersen
# 4   2014-11-24  530047381     Dennis & Robin McIntosh
# ..         ...        ...                         ...
# 320 2017-04-24  530009285  Monica & Magdaleno Cajero
# 321 2017-06-16  530020173     Kristi & Ronald Cortney
# 322 2017-07-12  530020041               Jason Hottell
# 323 2017-08-25  530010445          Lyle & Shonna Yung
# 324 2017-09-14  530151659     Robert & Fawney Vincent
#
#                              Buyer  \
# 0                    Preston Walls
# 1    Chauncey & Stephanie Pedersen
# 2                    Michael Mowry
# 3                      Roy Hammond
# 4          Marc & Elizabeth Taylor
# ..                             ...
# 320                   Donald Weeks
# 321           Toni & Edward Barnes
# 322                Robin Whitehead
# 323       Daniel & Mercedes Arnold
# 324      Christine & Eddie Sharkey
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0    SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                         KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2    CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3             SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4     ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                 ...         ...
# 320   TRACT IN E 1/2 NE 1/4 OF 10-14-54 (26.849 ACRES)    135000.0
# 321  TAX LOT 8 PART OF SE 1/4 OF THE NW 1/4 & NE 1/...    150499.0
# 322  TAX LOT 14 MORGANS SUBDIVISION IN E 1/2 OF SW ...    187000.0
# 323           PART OF S 1/2 S 1/2 6-14-55 30.012 ACRES    235000.0
# 324                4.954 ACRE TRACT IN SW 1/4 30-15-56    135000.0
#
#     Assessor Location
# 0             Kimball
# 1             Kimball
# 2             Kimball
# 3             Kimball
# 4             Kimball
# ..                ...
# 320        Rural Resi
# 321        Rural Resi
# 322        Rural Resi
# 323        Rural Resi
# 324        Rural Resi
#
# [325 rows x 7 columns]
#      Sale Date  Parcel ID                          Seller  \
# 0   2014-10-17  530041421           Robert & Denise Waite
# 1   2014-10-29  530035642              Elizabeth Shandera
# 2   2014-11-14  530032732                   Wilma Vencill
# 3   2014-11-14  530042800                 Krissy Petersen
# 4   2014-11-24  530047381         Dennis & Robin McIntosh
# ..         ...        ...                             ...
# 449 2020-02-15  530010518               Trevor L Chrystal
# 450 2020-03-13  530021609      Scott E & Susan L Lockwood
# 451 2020-03-14  530029103  Douglas J & Marvel L Linthicum
# 452 2020-04-01  530018365                   Walter L Wann
# 453 2020-07-24  530050439      Dwayne A & Jonita M Groves
#
#                                  Buyer  \
# 0                        Preston Walls
# 1        Chauncey & Stephanie Pedersen
# 2                        Michael Mowry
# 3                          Roy Hammond
# 4              Marc & Elizabeth Taylor
# ..                                 ...
# 449           Michael T & Renee A Geha
# 450          Dalton & Ainsley Lockwood
# 451       Trevor L & Nicole M Anderson
# 452                Robert D Dunkin III
# 453  Bradley Ray & Nicole Lynn Hottell
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0    SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                         KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2    CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3             SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4     ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                 ...         ...
# 449         1.907 ACRES IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 450                           23.147 ACRES IN 36-15-57    490000.0
# 451                LOT 3 PRAIRIE RIDGE ESTATE 17-15-55    255000.0
# 452                    TRACT IN NE 1/4 NW 1/4 31-15-55     70000.0
# 453               12.415 ACRE TRACT IN NE 1/4 29-15-55    135000.0
#
#     Assessor Location Assessed Value
# 0             Kimball            NaN
# 1             Kimball            NaN
# 2             Kimball            NaN
# 3             Kimball            NaN
# 4             Kimball            NaN
# ..                ...            ...
# 449        Rural Resi          74345
# 450        Rural Resi         300120
# 451        Rural Resi         206040
# 452        Rural Resi          87090
# 453        Rural Resi         197340
#
# [454 rows x 8 columns]
#      Sale Date  Parcel ID                    Seller  \
# 0   2014-10-17  530041421     Robert & Denise Waite
# 1   2014-10-29  530035642        Elizabeth Shandera
# 2   2014-11-14  530032732             Wilma Vencill
# 3   2014-11-14  530042800           Krissy Petersen
# 4   2014-11-24  530047381   Dennis & Robin McIntosh
# ..         ...        ...                       ...
# 616 2021-03-05  530010445           Daniel B Arnold
# 617 2021-03-25  530024640   Kathleen Atkins Trustee
# 618 2021-05-03  530005069  Garland & Megan Hamilton
# 619 2021-08-05  530010518  Michael T & Renee A Geha
# 620 2021-09-28  530016818         Barbara K Michael
#
#                                Buyer  \
# 0                      Preston Walls
# 1      Chauncey & Stephanie Pedersen
# 2                      Michael Mowry
# 3                        Roy Hammond
# 4            Marc & Elizabeth Taylor
# ..                               ...
# 616  Timothy Wayne & Dixie Lee Smith
# 617    Ryan Lukassen & Elyse Schlake
# 618                   Sara Silvanage
# 619                        Adam Geha
# 620                 Carmen M Jackman
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0    SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                         KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2    CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3             SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4     ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                 ...         ...
# 616                   6-14-55 PART OF S1/2S1/2 6-14-55    330000.0
# 617           25-16-54 A TRACT IN THE N/2NE/4 25-16-54    265000.0
# 618           6.502 ACRE TRACT IN NE1/4NE1/4 26-13-55     122000.0
# 619            1.907 A. IN SE CORNER OF SW 1/4 7-14-55     80000.0
# 620  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
#
#     Assessor Location Assessed Value
# 0             Kimball            NaN
# 1             Kimball            NaN
# 2             Kimball            NaN
# 3             Kimball            NaN
# 4             Kimball            NaN
# ..                ...            ...
# 616        Rural Resi         215195
# 617        Rural Resi         161020
# 618        Rural Resi         103510
# 619        Rural Resi          74345
# 620        Rural Resi         156655
#
# [621 rows x 8 columns]
#      Sale Date  Parcel ID                     Seller  \
# 0   2014-10-17  530041421      Robert & Denise Waite
# 1   2014-10-29  530035642         Elizabeth Shandera
# 2   2014-11-14  530032732              Wilma Vencill
# 3   2014-11-14  530042800            Krissy Petersen
# 4   2014-11-24  530047381    Dennis & Robin McIntosh
# ..         ...        ...                        ...
# 752 2018-06-15  530020696  Michael H & Karen M Isley
# 753 2018-07-06  530031094            Karla J Jenkins
# 754 2018-07-18  530151470  Jared C & Melissa L Reich
# 755 2018-08-01  530025779            Jeanne Anderson
# 756 2018-09-14  530026937           Mary Ann Felkins
#
#                              Buyer  \
# 0                    Preston Walls
# 1    Chauncey & Stephanie Pedersen
# 2                    Michael Mowry
# 3                      Roy Hammond
# 4          Marc & Elizabeth Taylor
# ..                             ...
# 752               James N Columbia
# 753          Marvin & Sandra Tabor
# 754                  Karla Jenkins
# 755               Cheryl Delaplane
# 756      John M & Alicia I Buchart
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0    SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                         KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2    CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3             SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4     ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                 ...         ...
# 752                         A TRACT IN SE 1/4 28-15-56    165000.0
# 753                 TRACT S OF UPRR IN SE 1/4 26-15-56    130000.0
# 754                  29.823 A TRACT IN NE 1/4 18-16-55    217500.0
# 755              TRACT IN WEST PART OF NW 1/4 32-16-55     67000.0
# 756  7.015 ACRES IN THE NE 1/4 OF THE NE 1/4 OF TH ...    180000.0
#
#     Assessor Location Assessed Value
# 0             Kimball            NaN
# 1             Kimball            NaN
# 2             Kimball            NaN
# 3             Kimball            NaN
# 4             Kimball            NaN
# ..                ...            ...
# 752        Rural Resi            NaN
# 753        Rural Resi            NaN
# 754        Rural Resi            NaN
# 755        Rural Resi            NaN
# 756        Rural Resi            NaN
#
# [757 rows x 8 columns]
#      Sale Date  Parcel ID                         Seller  \
# 0   2014-10-17  530041421          Robert & Denise Waite
# 1   2014-10-29  530035642             Elizabeth Shandera
# 2   2014-11-14  530032732                  Wilma Vencill
# 3   2014-11-14  530042800                Krissy Petersen
# 4   2014-11-24  530047381        Dennis & Robin McIntosh
# ..         ...        ...                            ...
# 889 2021-09-28  530016818              Barbara K Michael
# 890 2022-04-11  530015951    Sammie M & Lovina Gingerich
# 891 2022-04-28  530020041  Michael A & Clara Sue Salazar
# 892 2022-05-11  530151785          Jean A Mueller-Yanaga
# 893 2022-07-07  530023288             Central Properties
#
#                              Buyer  \
# 0                    Preston Walls
# 1    Chauncey & Stephanie Pedersen
# 2                    Michael Mowry
# 3                      Roy Hammond
# 4          Marc & Elizabeth Taylor
# ..                             ...
# 889               Carmen M Jackman
# 890     Sammie & Talia L Gingerich
# 891        Matthew & Crystal Brown
# 892                 Daniel Glasgow
# 893            Adair Holdings, LLC
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0    SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                         KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 2    CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3             SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# 4     ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9     102000.0
# ..                                                 ...         ...
# 889  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
# 890         23.540 ACRES IN SE 1/4 S. OF UPRR 29-15-54    167000.0
# 891  TAX LOT 14 MORGAN'S SUBDIVISION IN E 1/2 OF SW...    305000.0
# 892   TRACT IN SE 1/4 AND E 1/2 NE 1/4 SW 1/4 33-15-55    190000.0
# 893            9.883 ACRE TRACT IN N 1/2 N 1/2 6-16-53    126185.0
#
#     Assessor Location Assessed Value
# 0             Kimball            NaN
# 1             Kimball            NaN
# 2             Kimball            NaN
# 3             Kimball            NaN
# 4             Kimball            NaN
# ..                ...            ...
# 889        Rural Resi         156655
# 890        Rural Resi         190030
# 891        Rural Resi         150090
# 892        Rural Resi          96960
# 893        Rural Resi         126185
#
# [894 rows x 8 columns]

# %%
print(len(merged_df))
merged_df.sort_values(by='Sale Date')
# Out:
# 894
#      Sale Date  Parcel ID                    Seller  \
# 0   2014-10-17  530041421     Robert & Denise Waite
# 1   2014-10-29  530035642        Elizabeth Shandera
# 76  2014-11-06  530157938            William Spires
# 2   2014-11-14  530032732             Wilma Vencill
# 3   2014-11-14  530042800           Krissy Petersen
# ..         ...        ...                       ...
# 862 2022-08-12  530034344             Abraham Parra
# 863 2022-08-19  530042606           Dillon Hatfield
# 864 2022-08-29  530033615            Linda Williams
# 865 2022-09-09  530036843           Kimball DJ, LLC
# 866 2022-09-26  530045109  Johnny D & Dawn Clifford
#
#                                                  Buyer  \
# 0                                        Preston Walls
# 1                        Chauncey & Stephanie Pedersen
# 76                                      Andrew Knicely
# 2                                        Michael Mowry
# 3                                          Roy Hammond
# ..                                                 ...
# 862  Lynn Tornberg, James Cleveland & Shawna Cleveland
# 863                                     Carter Rompola
# 864                                  809 S Elm St, LLC
# 865                                Eldon & Kylee Lewis
# 866         Mario Leiva Duran & Mirna Azucena Guerrero
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 0    SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...     54500.0
# 1                         KIMBALL HEIGHTS ADD. LOT 13     140000.0
# 76                      3.99 A.TRACT IN SE1/4 28-15-56     80000.0
# 2    CLARKSON ADD. BLOCK 10 LOT 6 AND N. 25' OF LOT 7      57000.0
# 3             SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14       49600.0
# ..                                                 ...         ...
# 862                      FORSLINGS ADD. BLOCK 3 LOT 12    185000.0
# 863             SUNNYVIEW HEIGHTS ADD. BLOCK 12 LOT 10    125000.0
# 864                EAST MANOR FIRST ADD. BLOCK 1 LOT 9     83000.0
# 865  LEAMINGS ADD, BLOCK 8 LOT 3 AND THE N 1/2 OF L...    120000.0
# 866  BURG'S ADD. BLOCK 2 S 1/2 OF LOT 23 AND ALL LO...     39000.0
#
#     Assessor Location Assessed Value
# 0             Kimball            NaN
# 1             Kimball            NaN
# 76         Rural Resi            NaN
# 2             Kimball            NaN
# 3             Kimball            NaN
# ..                ...            ...
# 862           Kimball          37575
# 863           Kimball          94675
# 864           Kimball          46040
# 865           Kimball          70375
# 866           Kimball          39900
#
# [894 rows x 8 columns]

# %%
pd.set_option('display.max_rows', 100)
merged_df.loc[merged_df.duplicated(),:]
# Out:
#      Sale Date  Parcel ID                       Seller  \
# 213 2015-10-19  530035847              Donald Thompson
# 214 2015-10-26  530045036              William Loring
# 215 2015-10-27  530033003  William & Winifred Petersen
# 216 2015-11-12  530017318     James & Charlotta Young
# 217 2015-11-27  530033798           Marcelino Calderon
# ..         ...        ...                          ...
# 875 2021-06-05  530047640              Phillip G Niles
# 876 2021-06-14  530068389            Geraldine Leonard
# 877 2021-08-17  530048914            Marilyn A Morgart
# 884 2020-10-27  530109719              Terry Jefferson
# 889 2021-09-28  530016818            Barbara K Michael
#
#                                             Buyer  \
# 213                       Carolyn & Jennette Wood
# 214                                   Aleta Lewis
# 215                   Matthew & Rachel Merryfield
# 216                          Jose & Fatima Lozoya
# 217                       Daniel & Sherry Acheson
# ..                                            ...
# 875  Hermila Torres Zapata & Socorro Munoz Molina
# 876                     Bert & Debby Ruth Summers
# 877                                  Joan M Fluit
# 884                 Michael A & Clara Sue Salazar
# 889                              Carmen M Jackman
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 213                         KINGSWOOD FIRST ADD. LOT 1     62000.0
# 214  BURG'S ADD. BLOCK 2 ALL OF SUBLOT 1 OF  LOTS 1...     30000.0
# 215                   DOWD'S FIRST ADD. BLOCK 2 LOT 1      87500.0
# 216  PART OF THE SW 1/4 SOUTH OF THE UPRR    28-15-55      95000.0
# 217         FAIRVIEW ADD. BLOCK 4 LOTS 21-22-23 AND 24     30000.0
# ..                                                 ...         ...
# 875              BUSHNELL VILLAGE ADD. BLOCK 3 LOT 17      38000.0
# 876                ORKNEY'S ADD BLOCK 10 LOTS 1 AND 2      76000.0
# 877                ORKNEY'S ADD. BLOCK 13 LOTS 5 AND 6     52000.0
# 884         1.61 ACRE TRACT IN SE 1/4 NW 1/4 29-15-55     103000.0
# 889  TRACT 200 FEET BY 300 FEET IN THE N 1/2 OF THE...    225000.0
#
#     Assessor Location Assessed Value
# 213           Kimball            NaN
# 214           Kimball            NaN
# 215           Kimball            NaN
# 216           Kimball            NaN
# 217           Kimball            NaN
# ..                ...            ...
# 875          Bushnell          17670
# 876          Bushnell          41830
# 877          Bushnell          51940
# 884        Rural Resi          52275
# 889        Rural Resi         156655
#
# [253 rows x 8 columns]

# %%
sales_df = merged_df.loc[~merged_df.duplicated(),:]
print(len(sales_df))
# Out:
# 641

# %%
sales_df.sort_values(by='Parcel ID')
# Out:
#      Sale Date  Parcel ID                    Seller                     Buyer  \
# 448 2020-02-03  530005069             Kristine Carr  Garland & Megan Hamilton
# 618 2021-05-03  530005069  Garland & Megan Hamilton            Sara Silvanage
# 80  2015-09-04  530007347     Dolores Harms Trustee               Carl Butler
# 441 2018-12-19  530009099   Maury D & Diane B Horst      Larry & Denise Loose
# 209 2018-12-19  530009099   Maury D & Diane B Horst      Larry & Denise Loose
# ..         ...        ...                       ...                       ...
# 439 2018-10-26  530154424           Kelli Patterson      Ernest & Lea Hottell
# 442 2019-03-22  530157749    David & Joanna Hottell                 Liam Dunn
# 210 2019-03-22  530157749    David & Joanna Hottell                 Liam Dunn
# 76  2014-11-06  530157938            William Spires            Andrew Knicely
# 81  2015-09-30  530160227      Kyle & Laura Johnson       Jay & Ashley Thurin
#
#                                LEGAL DESCRIPTION   Sale Price  \
# 448                A 6.502 ACRE TRACT IN 26-13-55     80000.0
# 618      6.502 ACRE TRACT IN NE1/4NE1/4 26-13-55     122000.0
# 80                  TRACT IN E1/2 NE 1/4 14-13-58     40000.0
# 441            20.07 ACRE TRACT IN NE 1/4 5-14-54    105000.0
# 209            20.07 ACRE TRACT IN NE 1/4 5-14-54    105000.0
# ..                                            ...         ...
# 439             29.810 A TRACT IN SE 1/4 31-14-55    190000.0
# 442  TRACT IN SE 1/4 OF SE 1/4 OF SW 1/W 22-13-53    125000.0
# 210  TRACT IN SE 1/4 OF SE 1/4 OF SW 1/W 22-13-53    125000.0
# 76                 3.99 A.TRACT IN SE1/4 28-15-56     80000.0
# 81                     PART OF NE1/4SE1/4 2-15-55    220000.0
#
#     Assessor Location Assessed Value
# 448        Rural Resi         101495
# 618        Rural Resi         103510
# 80         Rural Resi            NaN
# 441        Rural Resi          62185
# 209        Rural Resi            NaN
# ..                ...            ...
# 439        Rural Resi         165030
# 442        Rural Resi         102330
# 210        Rural Resi            NaN
# 76         Rural Resi            NaN
# 81         Rural Resi            NaN
#
# [641 rows x 8 columns]

# %%
sales_df.loc[sales_df['Buyer'].str.contains("Lincoln")]
# Out:
#      Sale Date  Parcel ID            Seller  \
# 45  2016-02-11  530040220  Steven Cleveland
# 419 2020-08-28  530034360   William Russell
#
#                                    Buyer  \
# 45                Lincoln & Kelsey Brown
# 419  Lincoln Robert & Kelsey Leigh Brown
#
#                                     LEGAL DESCRIPTION   Sale Price  \
# 45   ORIGINAL KIMBALL ADD. BLOCK 10 LOTS 8   AND 9 ...     24000.0
# 419  FORSLINGS ADDITION BLOCK 3 N 10' OF LOT 13 AND...     67500.0
#
#     Assessor Location Assessed Value
# 45            Kimball            NaN
# 419           Kimball          72230

# %% [markdown]
# ## PID Requests

# %%
import requests
import json
from bs4 import BeautifulSoup as bs
from time import sleep
from random import randrange

# %%
# Define load_json function to process files
def load_json(results_file):
    pids = []
    with open(results_file, 'r') as data_file:
        data = data_file.readlines()
    for line in data:
        data_test = json.loads(line)
    for result in data_test['results']:
        pid = result.get('attributes', {}).get('PID')
        pids.append(pid)
    return pids

# %%
# URLs
#bulk_pid_url = "https://gis2.gworks.com/arcgis/rest/services/Kimball_County_NE_Assessor/MapServer/find"
#bulk_pid_query = "f=json&searchText=53000&layers=1,2&searchFields=&returnGeometry=true&sr=3857&token="
#detail_url = "https://report.gworks.com/report.ashx?county=kimball&id=530025930&type=assessor&subs=true&format=json"
#bulk_url = f"{bulk_pid_url}?{bulk_pid_query}"

# %%
bulk_pid_searches = []
bulk_pid_prefix = "5300"
for i in range(0,8):
    bulk_pid_searches.append(f"{bulk_pid_prefix}{i}")

# Add to catch any missed PIDs
bulk_pid_searches.append("530")
bulk_pid_searches.append("kimball")
bulk_pid_searches
# Out:
# ['53000',
#  '53001',
#  '53002',
#  '53003',
#  '53004',
#  '53005',
#  '53006',
#  '53007',
#  '530',
#  'kimball']

# %%
# Only need to run once to get query results
"""for pid in bulk_pid_searches:
    bulk_pid_url = "https://gis2.gworks.com/arcgis/rest/services/Kimball_County_NE_Assessor/MapServer/find"
    bulk_pid_query = f"f=json&searchText={pid}&layers=1,2&searchFields=&returnGeometry=true&sr=3857&token="
    bulk_url = f"{bulk_pid_url}?{bulk_pid_query}"
    r = requests.get(bulk_url)
    if r.status_code == 200:
        with open(f"{pid}_query.txt", "w") as out_file:
            out_file.writelines(r.text)
    sleep(10) # Sleep 10 seconds"""
# Out:
# 'for pid in bulk_pid_searches:\n    bulk_pid_url = "https://gis2.gworks.com/arcgis/rest/services/Kimball_County_NE_Assessor/MapServer/find"\n    bulk_pid_query = f"f=json&searchText={pid}&layers=1,2&searchFields=&returnGeometry=true&sr=3857&token="\n    bulk_url = f"{bulk_pid_url}?{bulk_pid_query}"\n    r = requests.get(bulk_url)\n    if r.status_code == 200:\n        with open(f"{pid}_query.txt", "w") as out_file:\n            out_file.writelines(r.text)\n    sleep(10) # Sleep 10 seconds'

# %%
query_files = []
for f in os.listdir():
    if f.__contains__("_query"):
        query_files.append(f)
query_files
# Out:
# ['53000_query.txt',
#  '53001_query.txt',
#  '53007_query.txt',
#  '53003_query.txt',
#  '53002_query.txt',
#  'kimball_query.txt',
#  '53004_query.txt',
#  '53005_query.txt',
#  '530_query.txt',
#  '53006_query.txt']

# %%
pid_set = set()
for f in query_files:
    pids = load_json(f)
    pid_set.update(pids)

print(f"There are {len(pid_set)} pids for Kimball County.")
# Out:
# There are 4352 pids for Kimball County.

# %%
from IPython.display import clear_output
requests.urllib3.disable_warnings()
def get_detail(pids):
    proxies = {"http": "http://206.233.177.254:80"}
    if not os.path.exists("./PID_Details"):
        os.mkdir("./PID_Details")
        print("Folder PID_Details Created")
    else:
        print("Folder PID_Details Exists")
    for idx,pid in enumerate(pids):
        wait_time = randrange(10,15)
        detail_url = f"https://report.gworks.com/report.ashx?county=kimball&id={pid}&type=assessor&subs=true&format=json"
        print(f"Processing {pid}...")
        r = requests.get(detail_url, proxies=proxies, verify=False)
        if r.status_code == 200:
            print(f"Request successful: {r.status_code}")
            with open(f"./PID_Details/{pid}_detail.json", 'w') as detail_file:
                detail_file.writelines(r.text)
                print(f"{pid}_detail.json written")
        else:
            print(f"Request Failed.\nStatus Code: {r.status_code}\n{r.text}")
        print(f"{len(pids) - (idx + 1)} PIDs left")
        print(f"Sleeping for {wait_time} seconds")
        sleep(wait_time)
        if(idx + 1) % 100 == 0:
            print(f"Processed {idx + 1} records. Pausing for 10 minutes")
            #sleep(600)
        clear_output(wait=True)

# %%
def existing_records(pid_set):
    existing_records = set()
    existing_files = os.listdir("PID_Details")
    for f in existing_files:
        pattern = r"(\d*)"
        pattern = re.compile(pattern)
        match = pattern.match(f)
        existing_records.add(match[0])
    print(len(pid_set))
    print(len(existing_records))
    need_details = set.difference(pid_set,existing_records)
    print(f"{len(need_details)} Records need to be processed.")
    print(need_details)
    return need_details

# %%
need_details = existing_records(pid_set)
# Out:
# 4352
# 4350
# 3 Records need to be processed.
# {'5300133312', '9999', '0'}

# %%
get_detail(need_details)
# Out:
# Folder PID_Details Exists
# Processing 5300133312...
# Request Failed.
# Status Code: 500
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Runtime Error</title>
#         <meta name="viewport" content="width=device-width" />
#         <style>
#          body {font-family:"Verdana";font-weight:normal;font-size: .7em;color:black;}
#          p {font-family:"Verdana";font-weight:normal;color:black;margin-top: -5px}
#          b {font-family:"Verdana";font-weight:bold;color:black;margin-top: -5px}
#          H1 { font-family:"Verdana";font-weight:normal;font-size:18pt;color:red }
#          H2 { font-family:"Verdana";font-weight:normal;font-size:14pt;color:maroon }
#          pre {font-family:"Consolas","Lucida Console",Monospace;font-size:11pt;margin:0;padding:0.5em;line-height:14pt}
#          .marker {font-weight: bold; color: black;text-decoration: none;}
#          .version {color: gray;}
#          .error {margin-bottom: 10px;}
#          .expandable { text-decoration:underline; font-weight:bold; color:navy; cursor:pointer; }
#          @media screen and (max-width: 639px) {
#           pre { width: 440px; overflow: auto; white-space: pre-wrap; word-wrap: break-word; }
#          }
#          @media screen and (max-width: 479px) {
#           pre { width: 280px; }
#          }
#         </style>
#     </head>
#
#     <body bgcolor="white">
#
#             <span><H1>Server Error in '/' Application.<hr width=100% size=1 color=silver></H1>
#
#             <h2> <i>Runtime Error</i> </h2></span>
#
#             <font face="Arial, Helvetica, Geneva, SunSans-Regular, sans-serif ">
#
#             <b> Description: </b>An application error occurred on the server. The current custom error settings for this application prevent the details of the application error from being viewed remotely (for security reasons). It could, however, be viewed by browsers running on the local server machine.
#             <br><br>
#
#             <b>Details:</b> To enable the details of this specific error message to be viewable on remote machines, please create a &lt;customErrors&gt; tag within a &quot;web.config&quot; configuration file located in the root directory of the current web application. This &lt;customErrors&gt; tag should then have its &quot;mode&quot; attribute set to &quot;Off&quot;.<br><br>
#
#             <table width=100% bgcolor="#ffffcc">
#                <tr>
#                   <td>
#                       <code><pre>
#
# &lt;!-- Web.Config Configuration File --&gt;
#
# &lt;configuration&gt;
#     &lt;system.web&gt;
#         &lt;customErrors mode=&quot;Off&quot;/&gt;
#     &lt;/system.web&gt;
# &lt;/configuration&gt;</pre>                      </code>
#
#                   </td>
#                </tr>
#             </table>
#
#             <br>
#
#             <b>Notes:</b> The current error page you are seeing can be replaced by a custom error page by modifying the &quot;defaultRedirect&quot; attribute of the application&#39;s &lt;customErrors&gt; configuration tag to point to a custom error page URL.<br><br>
#
#             <table width=100% bgcolor="#ffffcc">
#                <tr>
#                   <td>
#                       <code><pre>
#
# &lt;!-- Web.Config Configuration File --&gt;
#
# &lt;configuration&gt;
#     &lt;system.web&gt;
#         &lt;customErrors mode=&quot;RemoteOnly&quot; defaultRedirect=&quot;mycustompage.htm&quot;/&gt;
#     &lt;/system.web&gt;
# &lt;/configuration&gt;</pre>                      </code>
#
#                   </td>
#                </tr>
#             </table>
#
#             <br>
#
#             </font>
#
#     </body>
# </html>
#
# 2 PIDs left
# Sleeping for 14 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 get_detail(need_details)
#
# Cell In[21], line 24, in get_detail(pids)
#      22 print(f"{len(pids) - (idx + 1)} PIDs left")
#      23 print(f"Sleeping for {wait_time} seconds")
# ---> 24 sleep(wait_time)
#      25 if(idx + 1) % 100 == 0:
#      26     print(f"Processed {idx + 1} records. Pausing for 10 minutes")
#
# KeyboardInterrupt:

# %%
proxies = {"http": "http://65.20.235.40:8080"}
r = requests.get("https://report.gworks.com/report.ashx?county=kimball&id=530035669&type=assessor&subs=true&format=json", proxies=proxies, verify=False)
r.text
# Out:
# '{"items":[{"type":"report","title":"Buffalo County Assessor","template":"DefaultStyleTemplate","format":{},"items":[{"type":"table","title":"Parcel Information","formtype":"normal","HeaderFormat":"background-color: Black !important;","items":[{"type":"field","title":"Parcel ID:","formtype":"","HeaderFormat":"","items":["530035669"]},{"type":"field","title":"Map Number","formtype":"","HeaderFormat":"","items":[""]},{"type":"field","title":"State Geo Code","formtype":"","HeaderFormat":"","items":["2809-00-0-30041-000-0015"]},{"type":"field","title":"Cadastral #","formtype":"","HeaderFormat":"","items":[""]},{"type":"field","title":"Images","formtype":"","HeaderFormat":"","items":["  <a target=\'_blank\' href = \'https://kimball.gworks.com/photos/0530035669_2.jpg\' >Photo #1</a>  <a target=\'_blank\' href = \'https://kimball.gworks.com/photos/0530035669_3.jpg\' >Photo #2</a>  <a target=\'_blank\' href = \'https://kimball.gworks.com/photos/0530035669_4.jpg\' >Photo #3</a>  <a target=\'_blank\' href = \'https://kimball.gworks.com/photos/0530035669_1.jpg\' >Sketch #1</a>","",""]},{"type":"field","title":"Current Owner:","formtype":"","HeaderFormat":"","items":["DAVIS/VIRGINIA ROSE \\r704 S WEBSTER ST\\rKIMBALL, NE  69145"]},{"type":"field","title":"Situs Address:","formtype":"","HeaderFormat":"","items":["704 S WEBSTER STREET KIMBALL"]},{"type":"field","title":"Tax District:","formtype":"","HeaderFormat":"","items":["40"]},{"type":"field","title":"School District:","formtype":"","HeaderFormat":"","items":["KIMBALL #1, 53-0001"]},{"type":"field","title":"Account Type:","formtype":"","HeaderFormat":"","items":["Residential"]},{"type":"field","title":"Legal Description:","formtype":"","HeaderFormat":"","items":["KIMBALL HEIGHTS ADD. LOT 15 (CARD #12)**704 SOUTH WEBSTER STREET (1078382)"]},{"type":"field","title":"Lot Width:","formtype":"","HeaderFormat":"","items":["75.00"]},{"type":"field","title":"Lot Depth:","formtype":"","HeaderFormat":"","items":["140.00"]},{"type":"field","title":"Total Lot Size:","formtype":"","HeaderFormat":"","items":["10500.00 sq ft"]}]},{"type":"table","title":"Assessed Values","formtype":"list","HeaderFormat":"background-color: Black !important;","items":[{"type":"field","title":"Year","formtype":"list","HeaderFormat":"","items":["2023","2022"]},{"type":"field","title":"Total","formtype":"list","HeaderFormat":"","items":["$70,190","$74,065"]},{"type":"field","title":"Land","formtype":"list","HeaderFormat":"","items":["$11,900","$10,185"]},{"type":"field","title":"Outbuilding","formtype":"list","HeaderFormat":"","items":["$0","$0"]},{"type":"field","title":"Dwelling","formtype":"list","HeaderFormat":"","items":["$58,290","$63,880"]}]},{"type":"table","title":"Yearly Tax Information","formtype":"list","HeaderFormat":"background-color: Black !important;","items":[{"type":"field","title":"Year","formtype":"list","HeaderFormat":"","items":["2023"]},{"type":"field","title":"Amount","formtype":"list","HeaderFormat":"","items":["$1,297.14"]},{"type":"field","title":"Levy","formtype":"list","HeaderFormat":"","items":["1.959336"]}]},{"type":"table","title":"2023 Tax Levy","formtype":"list","HeaderFormat":"background-color: Black !important;","items":[{"type":"field","title":"Description ","formtype":"list","HeaderFormat":"","items":["COUNTY GENERAL","KIMBALL #1","WNCC","ESU #13","HISTORICAL SOCIETY","AG SOCIETY","KIMBALL AIRPORT GENERAL","KIMBALL CITY BOND","S.P.N.R.D","KIMBALL CITY GENERAL","KIMBALL AIRPORT BOND"]},{"type":"field","title":"Rate","formtype":"list","HeaderFormat":"","items":["0.47937200","0.90000000","0.09891400","0.01509400","0.00210400","0.01012800","0.01695600","0.00000000","0.04734200","0.36157200","0.02785400"]}]},{"type":"table","title":"Sales Information","formtype":"list","HeaderFormat":"background-color: Black !important;","items":[{"type":"field","title":"Sale Date","formtype":"list","HeaderFormat":"","items":["09/24/2019"]},{"type":"field","title":"Sale Price","formtype":"list","HeaderForm ...

# %% [raw]
# print(r.status_code)

# %%
pid_list = os.listdir("PID_Details")
len(pid_list)
# Out:
# 4350

# %%
f = pid_list[1]
print(f)
# Out:
# 530058146_detail.json

# %%
with open(f"PID_Details/{f}", 'r') as test_pid:
    [pid_data] = test_pid.readlines()

print(pid_data)
# Out:
# {"items":[{"type":"report","title":"Buffalo County Assessor","template":"DefaultStyleTemplate","format":{},"items":[{"type":"table","title":"Parcel Information","formtype":"normal","HeaderFormat":"background-color: Black !important;","items":[{"type":"field","title":"Parcel ID:","formtype":"","HeaderFormat":"","items":["530058146"]},{"type":"field","title":"Map Number","formtype":"","HeaderFormat":"","items":[""]},{"type":"field","title":"State Geo Code","formtype":"","HeaderFormat":"","items":["2827-29-0-00000-000-0002"]},{"type":"field","title":"Cadastral #","formtype":"","HeaderFormat":"","items":[""]},{"type":"field","title":"Images","formtype":"","HeaderFormat":"","items":["  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_246.jpg' >Photo #1</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_193.jpg' >Photo #2</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_194.jpg' >Photo #3</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_195.jpg' >Photo #4</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_196.jpg' >Photo #5</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_197.jpg' >Photo #6</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_198.jpg' >Photo #7</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_199.jpg' >Photo #8</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_200.jpg' >Photo #9</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_201.jpg' >Photo #10</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_202.jpg' >Photo #11</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_203.jpg' >Photo #12</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_204.jpg' >Photo #13</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_205.jpg' >Photo #14</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_206.jpg' >Photo #15</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_207.jpg' >Photo #16</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_208.jpg' >Photo #17</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_209.jpg' >Photo #18</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_210.jpg' >Photo #19</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_211.jpg' >Photo #20</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_212.jpg' >Photo #21</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_213.jpg' >Photo #22</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_214.jpg' >Photo #23</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_215.jpg' >Photo #24</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_216.jpg' >Photo #25</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_217.jpg' >Photo #26</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_218.jpg' >Photo #27</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_219.jpg' >Photo #28</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_220.jpg' >Photo #29</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_221.jpg' >Photo #30</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_222.jpg' >Photo #31</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_223.jpg' >Photo #32</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_224.jpg' >Photo #33</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_225.jpg' >Photo #34</a>  <a target='_blank' hr ...

# %%
pid_json = json.loads(pid_data)

# %%
print(pid_json)
# Out:
# {'items': [{'type': 'report', 'title': 'Buffalo County Assessor', 'template': 'DefaultStyleTemplate', 'format': {}, 'items': [{'type': 'table', 'title': 'Parcel Information', 'formtype': 'normal', 'HeaderFormat': 'background-color: Black !important;', 'items': [{'type': 'field', 'title': 'Parcel ID:', 'formtype': '', 'HeaderFormat': '', 'items': ['530058146']}, {'type': 'field', 'title': 'Map Number', 'formtype': '', 'HeaderFormat': '', 'items': ['']}, {'type': 'field', 'title': 'State Geo Code', 'formtype': '', 'HeaderFormat': '', 'items': ['2827-29-0-00000-000-0002']}, {'type': 'field', 'title': 'Cadastral #', 'formtype': '', 'HeaderFormat': '', 'items': ['']}, {'type': 'field', 'title': 'Images', 'formtype': '', 'HeaderFormat': '', 'items': ["  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_246.jpg' >Photo #1</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_193.jpg' >Photo #2</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_194.jpg' >Photo #3</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_195.jpg' >Photo #4</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_196.jpg' >Photo #5</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_197.jpg' >Photo #6</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_198.jpg' >Photo #7</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_199.jpg' >Photo #8</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_200.jpg' >Photo #9</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_201.jpg' >Photo #10</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_202.jpg' >Photo #11</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_203.jpg' >Photo #12</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_204.jpg' >Photo #13</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_205.jpg' >Photo #14</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_206.jpg' >Photo #15</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_207.jpg' >Photo #16</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_208.jpg' >Photo #17</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_209.jpg' >Photo #18</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_210.jpg' >Photo #19</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_211.jpg' >Photo #20</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_212.jpg' >Photo #21</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_213.jpg' >Photo #22</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_214.jpg' >Photo #23</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_215.jpg' >Photo #24</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_216.jpg' >Photo #25</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_217.jpg' >Photo #26</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_218.jpg' >Photo #27</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_219.jpg' >Photo #28</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_220.jpg' >Photo #29</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_221.jpg' >Photo #30</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_222.jpg' >Photo #31</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_223.jpg' >Photo #32</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530058146_224.jpg' >Photo #33</a>  <a target='_blank' href = 'https://kimball.gworks. ...

# %%
parcel_info = pid_json['items'][0]['items'][0]['items'][0]['items']
print(parcel_info)
# Out:
# ['530048981']

# %%
print(json.dumps(pid_json, indent=4))
# Out:
# {
#     "items": [
#         {
#             "type": "report",
#             "title": "Buffalo County Assessor",
#             "template": "DefaultStyleTemplate",
#             "format": {},
#             "items": [
#                 {
#                     "type": "table",
#                     "title": "Parcel Information",
#                     "formtype": "normal",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Parcel ID:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "530048981"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Map Number",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 ""
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "State Geo Code",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2813-00-0-10005-014-0001"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Cadastral #",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 ""
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Images",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530048981_2.jpg' >Photo #1</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530048981_3.jpg' >Photo #2</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530048981_4.jpg' >Photo #3</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530048981_1.jpg' >Sketch #1</a>",
#                                 "",
#                                 ""
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Current Owner:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "GROVER/NATIAYA \r404 S WEBSTER ST\rKIMBALL, NE  69145"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Situs Address:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "116  WALNUT STREET BUSHNELL"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Tax District:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "65"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "School District:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "KIMBALL #1, 53-0001"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Account Type:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Residential"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Legal Description:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "ORKNEY'S ADD. BLOCK 14 LOTS 1-2-3 AND 4 (CARD #63) ** 116 WALNUT STREET"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Width:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "200.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Depth:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "140.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Total Lot Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "28000.00 sq ft"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Assessed Values",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Year",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2023",
#                                 "2022"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Total",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$15,795",
#                                 "$10,140"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Land",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$5,250",
#                                 "$7,840"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Outbuilding",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$1,315",
#                                 "$285"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Dwelling",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$9,230",
#                                 "$2,015"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Yearly Tax Information",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Year",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2023"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Amount",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$304.86"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Levy",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2.041432"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "2023 Tax Levy",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Description ",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "COUNTY GENERAL",
#                                 "KIMBALL #1",
#                                 "BUSHNELL-JOHNSON FIRE",
#                                 "WNCC",
#                                 "ESU #13",
#                                 "HISTORICAL SOCIETY",
#                                 "AG SOCIETY",
#                                 "BUSHNELL VILLAGE",
#                                 "S.P.N.R.D"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Rate",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "0.47937200",
#                                 "0.90000000",
#                                 "0.04026700",
#                                 "0.09891400",
#                                 "0.01509400",
#                                 "0.00210400",
#                                 "0.01012800",
#                                 "0.44821100",
#                                 "0.04734200"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "5 Year Sales History",
#                     "formtype": "normal",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "No previous sales information is available (for the past 5 years)."
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Property Classification",
#                     "formtype": "doubleTable",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Status:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Improved"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Location:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Urban"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Property Class:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Residential"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "City Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "101-799"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Zoning:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 " "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "20,001 sq. ft. - .99 ac."
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Land Information",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Lot Width (ft)",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "200.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Depth (ft)",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "140.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Description",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "200.00 x 140.00 FEET"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Size",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "28000.00 sq ft"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Residential Datasheet",
#                     "formtype": "doubleTable",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Zoning:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 " "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Quality:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Fair"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Year Built:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1963"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Condition:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Worn Out"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Exterior:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "100%   Aluminum Lap "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Style:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "100%   Singlewide "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Bedrooms:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "4"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Bathrooms:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Plumbing Fixtures:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "5"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Heating/Cooling:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 " 100%   Forced Air Furnace "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Basement Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "0 sq. ft"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Min Finish:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "0 sq. ft"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Building Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1,067 sq. ft"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Part Finish:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "0 sq. ft"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Dwelling Data",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Description",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Floor Allowance",
#                                 "Skirting, Plywood/Hardboard",
#                                 "Fireplace, Prefabricated",
#                                 "Raised Slab Porch",
#                                 "Open Slab Porch",
#                                 "CANOPY, ROOF/SLAB"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Units",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1,067",
#                                 "158",
#                                 "1",
#                                 "8",
#                                 "8",
#                                 "40"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Value",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "N/A",
#                                 "N/A",
#                                 "N/A",
#                                 "N/A",
#                                 "N/A",
#                                 "N/A"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Outbuilding Data",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Description",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Tool Shed"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Units",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "240"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Year Built",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1995"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Cost",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$1,315"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Photo/Sketch",
#                     "formtype": "normal",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "<img id='photo1' src = 'https://kimball.gworks.com/photos/0530048981_2.jpg'style='width: 100%'   '/>",
#                                 "<img id='sketch1' src = 'https://kimball.gworks.com/photos/0530048981_1.jpg'style='width: 100%' '/>"
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %%
sales_history = pid_json['items'][0]['items'][4]['items']

# %%
print(sales_history[0]['items'])
# Out:
# ['No previous sales information is available (for the past 5 years).']

# %%
def get_sales_info(pid):
    sales_string = "None"
    with open(f"PID_Details/{pid}") as pid_file:
        [raw_text] = pid_file.readlines()
    data = json.loads(raw_text)
    try:
        sales_group = data['items'][0]['items'][4]['items']
        sales_string = sales_group[0]
    except Exception as e:
        print(f"{e}")
    return sales_string

# %%
for pid in pid_list:
    sales_history = get_sales_info(pid)
    print(sales_history)
# Out:
# list index out of range
# None
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['03/19/2019']}
# {'items': ['802', '1301', '1327', '1372', '1510', '1578', '1739', '5607', '6030', '6032', '6041', '800'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1735', '1739', '6032', '6041', '801', '802', '1524', '1735', '1739', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/28/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1510', '6032', '1500', '1508', '1510', '1735', '6032', '1508']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '802', '800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['950', '1186', '1327', '1414', '1508', '800', '1186', '1327', '1508', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1739', '1744', '5800', '6041', '1524', '1739', '5800', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['950']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['09/28/2023', '07/11/2022', '07/11/2022']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1725', '1745', '5800', '6032', '6041', '1511', '1725', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1512', '1739', '6032', '6041', '1512', '1739', '6032', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6032', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1735', '1745', '6041', '802', '1660', '1735', '1745', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/23/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1735', '1739', '1744', '5800', '6032', '6041', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['75.00']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['09/16/2021', '12/20/2019']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1500', '1508', '1739', '6032', '6041', '1372', '1500', '1508', '1739', '6032', '6041']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['07/23/2021', '04/18/2021', '04/09/2021']}
# {'items': ['07/12/2023'], 'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1512', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '1500', '1508', '1511', '1500', '1508', '1511', '1372', '1508', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1739', '6041', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1660', '1725', '1744', '6041', '1725', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '1414', '1510', '5607', '5866', '5950', '1327', '1414', '1510', '5607', '5950', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['0.00']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['930', '931', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['04/29/2021']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['08/16/2021']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['03/27/2020']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1739', '6041', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1510', '1739', '6023', '6030', '6032', '6041', '1500', '1508', '1510', '1735', '1739', '6023', '6030', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '6023', '1327']}
# {'items': ['1524', '1660', '1739', '1744', '6032', '6041', '802', '1524', '1739', '1744', '6032', '6041', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['10/30/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '5800', '6032', '6041', '1739', '1744', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1739', '5800', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['02/16/2022']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1510', '1735', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['901', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/11/2022']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['07/06/2020']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '5607', '6041', '1301', '1372', '5607', '6032', '6041', '1372', '5607', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['435.80']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1327', '1508', '1739', '6023', '6041', '1301', '1327', '1508', '1739', '6023', '6041', '1301', '1327', '1500', '1739', '6023', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1524', '1735', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '1372', '1508', '5607', '6041', '1327', '1372', '1508', '5607', '6041']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['12/09/2021', '10/23/2020']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1725', '1739', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1372', '1739', '6030', '6032', '6041', '800', '803', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '6032', '6041', '1508', '6032', '1508', '1511', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['02/05/2019']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '5800', '6032', '1508', '1511', '5800', '6032', '1500', '1508', '1511', '5800', '6032']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1327', '5866', '6041', '802', '1327', '6041', '1301', '1327', '5866', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Unimproved']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['03/02/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1618', '1650', '5102', '5966', '6041', '802', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['6032', '6041']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1510', '1739', '6032', '6041', '802', '1739', '6032', '6041', 'ROAD']}
# {'items': ['802', '1327', '1372', '1739', '5607', '6032', '6041', '800', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['04/09/2021']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['03/29/2019', '03/29/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1524', '1660', '1735', '6032', '6041', '802', '1524', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['5607', '5950', '6030', '6032', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': 'Occupancy', 'formtype': 'list', 'HeaderFormat': '', 'items': ['100%   Service Repair Garage ', '21%   Administrative Office 79%   Municipal Service Garage ', '100%   Service Garage Shed ']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['50.00']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '1578', '5800', '6032', '1508', '1578', '1500', '1508', '1511', '1578', '5800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '5800', '6032', '6041', '1511', '5800', '6032', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '5800', '1508', '1511', '1578', '5800', '1508', '5800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '802', '1500', '1508', '1578', '800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1512', '1739', '6032', '6041', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['11/21/2023', '03/21/2019']}
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Unimproved']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['11/25/2020']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '1739', '6032', '6041', '1739', '6032']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['08/30/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1524', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['03/10/2023', '11/15/2021', '06/03/2020']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1735', '1739', '6032', '6041', '6032', '6041']}
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Unimproved']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1501', '1508', '1511', '6041', '1508', '6041', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '6041']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['06/10/2021']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901', '902', '903', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/13/2022']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6041', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1501', '1524', '6041', '1501', '1524', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '6032', '6041', '1508', '1511', '6032', '6041', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1739', '1744', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1512', '1524', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1511', '6041', '1500', '1511', '1512', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1735', '5800', '6032', '6041', '802', '1725', '1735', '1739', '1745', '5800', '6032', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '6041', '6041']}
# list index out of range
# None
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['08/09/2023']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920']}
# {'items': ['900', '901'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1739', '1744', '6041', '1524', '1739', '1744', '6041', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '1745', '5800', '6041', '801', '802', '1739', '1745', '5800', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['6032', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '6032']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1650', '1508', '1511', '1578', '1650', '6041', '802', '1508', '1511', '1650', '6041', '1508', '1511', '1650', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1512', '1660', '1739', '6041', '1660', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '5866']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920', '921']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['6041', '1739', '6032', '6041', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['06/14/2023', '12/30/2020']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/11/2022']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['05/01/2019', '04/23/2019']}
# {'items': ['1739', '1744', '6041'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/09/2020']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['11/25/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1327', '6032', '6041', '1301', '1327', '6032', '6041', '1301', '1327', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['10/13/2022']}
# {'items': ['50.00'], 'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '1508', '1510', '1511', '5800', '6023', '6032', '6041', '1372', '1510', '1511', '6023', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1739', '1744', '5800', '6041', '1524', '1739', '5800', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6032', '6041', '1301', '1327', '1372', '1508', '1739', '5607', '6032', '6041', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '1725', '1739', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['5800', '6032', '1725', '1739', '5800', '6032', '6041', '1739', '5800', '6032', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1739', '6041', '1524', '1725', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1617', '1618', '1650', '5102', '5800', '6041', '1618', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['07/18/2019', '04/24/2019', '04/24/2019']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['10/11/2022']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1735', '1739', '6032', '6041', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1501', '1508', '1511', '802', '1508']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['09/03/2020']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['11/23/2022', '01/11/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '1735', '1739', '5800', '6032', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1500', '1508', '1524', '1735', '6032', '6041', 'ROAD']}
# list index out of range
# None
# {'items': ['1500', '1501', '1508', '5800', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1744', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6041', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1510', '6023', '1500', '1508', '1510', '6023', '1500', '1510', '6023', '6030', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1735', '1745', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['100.00']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['25.00']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '5800', '6032', '6041', '1739', '1744', '5800', '6032', '6041', '1739', '1744', '6032', '6041']}
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Improved']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['02/08/2022']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['12/02/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '5800', '1500', '1508', '5800', '802', '1508', '1511', '5800', '800', 'ROAD']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'items': ['1512', '1735', '1739', '6032', '6041', '802', '6032', '6041', '800', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '1500', '1508', '1578', '1739', '5800', '6041', '802', '1372', '1500', '1508', '1578', '1739', '5800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['05/02/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['801', '802', '1508', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1508', '1524', '1739', '5800', '6032', '6041', '1301', '1508', '1524', '1739', '5800', '6032', '6041', '1739', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '800', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1500', '1508', '1511', '1739', '6032', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1809', '5100', '5101', '5800', '6032', '6041', '5100', '6032', '6041', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1725', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1327', '1739', '5607', '6032', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['05/26/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '1508', '5607', '6032', '6041']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['03/04/2022', '03/04/2022']}
# list index out of range
# None
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1512', '1739', '1744', '6032', '6041', '1508', '1512', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1660', '1735', '6041', '802', '1524', '1660', '1735', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '1744', '6041']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['07/02/2020']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['05/18/2023'], 'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1510', '1512', '1739', '5607', '5966', '6023', '6030', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['950']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'items': ['03/30/2022'], 'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901', '902', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '6041', '1372', '1508', '1511', '6032', '6041', '1508', '1511', '1739', '6032', '6041', 'ROAD']}
# list index out of range
# None
# {'items': ['1372', '1500', '1508', '1511', '1578', '6032', '802', '1372', '1500', '1508', '1511', '1578', '6032', '800', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['08/02/2023', '10/08/2021', '10/08/2021']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1660', '1739', '1744', '6041', '802', '1739', '1744', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['10/30/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['901', '902']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['04/21/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '5800', '6032', '6041', '1508', '1739', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['10/14/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1739', '1744', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1512', '1735', '1739', '5800', '6032', '6041', '802', '1511', '1739', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1186', '1301', '1327', '1414', '5607', '5866', '5867', '6023', '801', '802', '1186', '1301', '1327', '1414', '5607', '5867', '6023']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1745', '5800', '6032', '6041', '1524', '6032', '6041']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['150.00']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6041', '1725', '1739', '6041', '802', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'items': ['12/06/2021', '01/22/2021'], 'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '1739', '5800', '6032', '6041', '1508', '1511', '1739', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['09/13/2021']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['05/26/2021', '12/30/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1660', '1735', '1744', '6041', '1524', '6041', 'ROAD']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920', '921']}
# {'items': ['930'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1660', '1725', '1744', '6032', '6041', '1744', '6032', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '5607', '6032', '6041']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['07/15/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6032', '6041', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1739', '6041', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/11/2022']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['70.00']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['12/28/2020']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1500', '1660', '1725', '1739', '1745', '6032', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1735', '1739', '1744', '5800', '6041']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['08/17/2021', '08/17/2021', '08/17/2021']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['04/14/2023']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '1512', '802', '1508', '1511', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '801', '802', '1186', '1327', '1508', '1511', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '5800', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1327', '1508']}
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Unimproved']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6032', '6041', '1739', '6032', '6041']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1510', '1511', '6023', '6032', '1510', '6023', '6030', '6032', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['07/29/2019', '02/26/2019']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1512', '1524', '1660', '1735', '6041', '1524', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['6030', '6032']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1510', '6023', '1500', '1508', '1510', '5607', '6023', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1512', '6032', 'EXEMPT', '1512', '1500', '1512', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1578', '5800', '1500', '1508', '1511', '1578', '5800', '802', '1500', '1508', '1578', '800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1508', '5866', '1301', '1508', '5866', '1301', '1508', '5866']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'items': ['1739', '5800', '6032', '6041', '1725', '1739', '5800', '6032', '6041', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1744', '6032', '6041', '802', '1725', '1744', '6032', '6041', '800', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['5800', '6041', '802', '1725', '1744', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['02/11/2019']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1186', '1327', '1414', '1508', '802', '1186', '1327', '1414', '1508', '1186', '1327', '1414', '1508', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1327', '1508', '802', '1301', '1327', '1508', '1327', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['805', '1301', '1372', '1500', '1508', '1578', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['12/11/2023', '11/29/2023', '02/28/2023', '04/19/2021']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1301', '1327', '5866', '5867', '6041', '1301', '5866', '5867', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['50.00']}
# {'items': ['1327', '1508', '6041', '1327', '1508', '6041', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/24/2023']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1744', '1745', '5800', '6032', '6041', '1739', '6032', '6041', 'ROAD']}
# list index out of range
# None
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['12/31/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['802', '1524', '1744', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1735', '6041', '1524', '1735', '6041', '1524', '6041', 'ROAD']}
# list index out of range
# None
# ...
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['950']}
# {'type': 'field', 'title': 'Lot Width (ft)', 'formtype': 'list', 'HeaderFormat': '', 'items': ['50.00']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['09/10/2021']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1735', '1739', '6041', '1735', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'items': ['05/01/2019', '04/23/2019'], 'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1660', '1725', '1739', '1744', '6041', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1744', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '6041']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['05/24/2023', '12/11/2021', '02/04/2021', '02/04/2021']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1512', '1524', '1660', '6041']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'items': ['1500', '1501', '1508', '1578', '1372', '1500', '1508', '1578', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '1500', '1508', '1510', '1578', '1739', '5607', '6032', '6041', 'ROAD']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['11/08/2021', '03/12/2020']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1725', '1735', '1739', '6041', 'ROAD']}
# {'items': ['1745', '802', '1745', '6032', '6041', '800'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1660', '1725', '1735', '1745', '6032', '6041']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '1512', '6041', '802', '1508', '1512', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['6041', '802', '1744', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['950', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1735', '6032', '6041', '1500', '1508', '5800', '6032', '6041', '802', '1500', '1508', '1524', '1735', '5800', '6032', '6041', '800', '803', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1744', '6041', '802']}
# {'items': ['1372', '1725', '1739', '6032', '6041', 'ROAD'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1500', '1511', '1512', '1650', '1739', '6032', '1739', '6032'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920', '921', '922', '923']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '6030', '6032']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '1578', '1660', '1725', '1735', '1739', '6032', '6041', '1508', '1511', '1578', '1739', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1739', '6041', '802', '1725', '1739', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['02/12/2021']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1508', '1524', '6032', '6041', '1524', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['08/01/2020']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['10/31/2023', '01/30/2023']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '1735', '1508', '1735', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1512', '1524', '1735', '6032', '6041', '1511', '1512', '1524', '1735', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1735', '5800', '6032', '6041', '1524', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1524', '1744', '5800', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['09/24/2021']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['920', '921']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['05/15/2023']}
# {'items': ['1301', '1327', '1508', '1578', '1745', '6032', '6041', '1301', '1327', '1508', '1578'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['950']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['05/18/2020']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1725', '801', '802', '800', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['04/05/2022']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1372', '1500', '1508', '1511', '1660', '6032', '1372', '1500', '1508', '6032', 'ROAD']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Unimproved']}
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Unimproved']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1414', '1508', '1327', '1508', '1327', '1414', '1508', '1327', '1508', 'ROAD']}
# {'items': ['1725', '1739', '6032', '6041', '1725', '1739', '5800', '6032', '6041'], 'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1739', '6032', '6041', '1511', '1512', '1660', '1739', '6032', '6041', '6032', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '5800', '6032', '6041', '802', '1511', '1524', '6032', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1501', '1511', '1512', '1524', '6041', '802', '1501', '1511', '1512', '1524', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ["<img id='photo1' src = 'https://kimball.gworks.com/photos/0530048531_1.jpg'style='width: 100%'   '/>", '']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1744', '1745', '6041', '1744', '1745', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1511', '1512', '5800', '6032', '6041', '6032', '6041', '1511', '1512', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1512', '6041', '1508', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1327', '1510', '5607', '6023', '6041', '802', '1327', '1500', '1510', '5607', '6023', '6041', '800', 'ROAD']}
# {'type': 'field', 'title': 'Status:', 'formtype': '', 'HeaderFormat': '', 'items': ['Unimproved']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '5800', '1508', '1511', '1508', '1511', '5800', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901', '902', '903', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '802', '1508', '1511', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '1744', '6041', '1739', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '1511', '1512', '1660', '6041', '1500', '1660', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1660', '1725', '1744', '6041', '1725', '1744', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['01/20/2021', '06/15/2020']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1511', '1512', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# list index out of range
# None
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1508', '1510', '1511', '6032', '6041', '1508', '1510', '1511', '1512', '6032', '6041', '1510', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '5607', '6030', '6032', '6041']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['07/19/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1660', '1735', '6041', '1512', '1524', '1735', '6041', '1524', '6041']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['06/22/2023']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1739', '1744', '6041', '1660', '1725', '1739', '1744', '6041', '1660', '1725', '1739', '1744', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1186', '1327', '802', '1186', '1327', '5607', '6032', '6041', '1186', '1327', '5607', '6032', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1660', '1725', '1744', '6032', '6041', '802', '1660', '1725', '1744', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1739', '5800', '6041', '1524', '6041', 'ROAD']}
# {'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': '', 'items': ['No previous sales information is available (for the past 5 years).']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['900', '901']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['11/29/2021', '03/26/2019']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1501', '1508', '1511', '1512', '1660', '6032', '6041', '802', '1508', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1508', '5800', '802', '1508', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1524', '1739', '1744', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '1744', '6032', '6041', '1739', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1510', '1511', '1725', '1739', '5800', '6032', '6041', 'ROAD']}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['04/12/2022', '01/14/2022', '02/21/2021']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1739', '1744', '6032', '6041', '1739', '6032', '6041']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1725', '1739', 'ROAD']}
# {'type': 'field', 'title': 'Soil Symbol', 'formtype': 'list', 'HeaderFormat': '', 'items': ['1500', '1725', '1739', '6041', 'ROAD']}
# {'items': ['No previous sales information is available (for the past 5 years).'], 'type': 'field', 'title': '', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Sale Date', 'formtype': 'list', 'HeaderFormat': '', 'items': ['08/06/2021']}

# %%
sales_pids = sales_df['Parcel ID']

test_price = sales_df.loc[sales_df['Parcel ID']== sales_pids[0], 'Sale Price']
print(test_price)
# Out:
# 0      54500.0
# 421    52000.0
# Name: Sale Price, dtype: float64

# %%
def get_pid_info(pid):
        with open(f"PID_Details/{pid}_detail.json") as pid_file:
            [raw_text] = pid_file.readlines()
        data = json.loads(raw_text)
        return data

# %%
def get_json_len(pid):
    path = f"PID_Details/{pid}_detail.json"
    if os.path.exists(path):
        with open(path) as pid_file:
            [raw_text] = pid_file.readlines()
        data = json.loads(raw_text)
        parcel_data = data['items'][0]['items']
        print(len(parcel_data))

# %%
for pid in sales_pids:
    get_json_len(pid)
# Out:
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 11
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 10
# 10
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 10
# 12
# 11
# 11
# 11
# 10
# 10
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 8
# 11
# 11
# 11
# 10
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 10
# 11
# 10
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 11
# 10
# 11
# 10
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 10
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 12
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 10
# 10
# 10
# 11
# 11
# 10
# 11
# 10
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 10
# 10
# 11
# 10
# 10
# 11
# 11
# 10
# 11
# 12
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 12
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 11
# 10
# 10
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 10
# 12
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 10
# 11
# 11
# 11
# 8
# 11
# 11
# 10
# 10
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 10
# 11
# 10
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 10
# 11
# 10
# 10
# 11
# 10
# 10
# 11
# 11
# 11
# 10
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11

# %%
test = get_pid_info(sales_pids[0])

# %%
print(json.dumps(test, indent=4))
# Out:
# {
#     "items": [
#         {
#             "type": "report",
#             "title": "Buffalo County Assessor",
#             "template": "DefaultStyleTemplate",
#             "format": {},
#             "items": [
#                 {
#                     "type": "table",
#                     "title": "Parcel Information",
#                     "formtype": "normal",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Parcel ID:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "530041421"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Map Number",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 ""
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "State Geo Code",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2809-00-0-30059-003-0013"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Cadastral #",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 ""
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Images",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_4.jpg' >Photo #1</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_5.jpg' >Photo #2</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_6.jpg' >Photo #3</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_7.jpg' >Photo #4</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_8.jpg' >Photo #5</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_3.jpg' >Photo #6</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_2.jpg' >Photo #7</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_1.jpg' >Sketch #1</a>  <a target='_blank' href = 'https://kimball.gworks.com/photos/0530041421_9.jpg' >Site Plan #1</a>",
#                                 "",
#                                 ""
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Current Owner:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "BESHORE/BRADLEY \r4500 SENECA ST #38\rFORT COLLINS, CO  80526"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Situs Address:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "603 S MYRTLE STREET KIMBALL"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Tax District:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "40"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "School District:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "KIMBALL #1, 53-0001"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Account Type:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Residential"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Legal Description:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND ALL LOT 14 (CARD #31)** 603 SOUTH   MYRTLE STREET"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Width:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "75.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Depth:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "140.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Total Lot Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "10500.00 sq ft"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Assessed Values",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Year",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2023",
#                                 "2022"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Total",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$60,885",
#                                 "$60,170"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Land",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$11,900",
#                                 "$10,185"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Outbuilding",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$590",
#                                 "$195"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Dwelling",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$48,395",
#                                 "$49,790"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Yearly Tax Information",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Year",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2023"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Amount",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$1,125.16"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Levy",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1.959336"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "2023 Tax Levy",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Description ",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "COUNTY GENERAL",
#                                 "KIMBALL #1",
#                                 "WNCC",
#                                 "ESU #13",
#                                 "HISTORICAL SOCIETY",
#                                 "AG SOCIETY",
#                                 "KIMBALL AIRPORT GENERAL",
#                                 "KIMBALL CITY BOND",
#                                 "S.P.N.R.D",
#                                 "KIMBALL CITY GENERAL",
#                                 "KIMBALL AIRPORT BOND"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Rate",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "0.47937200",
#                                 "0.90000000",
#                                 "0.09891400",
#                                 "0.01509400",
#                                 "0.00210400",
#                                 "0.01012800",
#                                 "0.01695600",
#                                 "0.00000000",
#                                 "0.04734200",
#                                 "0.36157200",
#                                 "0.02785400"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Sales Information",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Sale Date",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "09/03/2020"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Sale Price",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$52,000.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Book & Page",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "81 / 718"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Grantor",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "WALLS/PRESTON C "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Parcel Ids",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 ""
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Property Classification",
#                     "formtype": "doubleTable",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Status:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Improved"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Location:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Urban"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Property Class:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Residential"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "City Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2,501-5,000"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Zoning:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Single Family"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "10,000-20,000 sq. ft."
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Land Information",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Lot Width (ft)",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "75.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Depth (ft)",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "140.00"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Description",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "75.00 x 140.00 FEET"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Lot Size",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "10500.00 sq ft"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Residential Datasheet",
#                     "formtype": "doubleTable",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Zoning:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Single Family"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Condition:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Average"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Year Built:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1945"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Style:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "100%   One Story "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Exterior:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "100%   Frame, Stucco "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Bathrooms:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1.50"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Bedrooms:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "2"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Heating/Cooling:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 " 100%   Forced Air Furnace "
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Plumbing Fixtures:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "7"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Min Finish:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "0 sq. ft"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Basement Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "336 sq. ft"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Part Finish:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "336 sq. ft"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Building Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1,070 sq. ft"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Garage 1:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Attached Garage"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Quality:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Fair"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Garage 1 Size:",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "252 sq. ft"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Dwelling Data",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Description",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Floor Allowance",
#                                 "Wood Deck",
#                                 "Patio"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Units",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1,070",
#                                 "39",
#                                 "180"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Value",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "N/A",
#                                 "N/A",
#                                 "N/A"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Outbuilding Data",
#                     "formtype": "list",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "Description",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "Tool Shed",
#                                 "Tool Shed"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Units",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "96",
#                                 "60"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Year Built",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "1992",
#                                 "1992"
#                             ]
#                         },
#                         {
#                             "type": "field",
#                             "title": "Cost",
#                             "formtype": "list",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "$280",
#                                 "$310"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "table",
#                     "title": "Photo/Sketch",
#                     "formtype": "normal",
#                     "HeaderFormat": "background-color: Black !important;",
#                     "items": [
#                         {
#                             "type": "field",
#                             "title": "",
#                             "formtype": "",
#                             "HeaderFormat": "",
#                             "items": [
#                                 "<img id='photo1' src = 'https://kimball.gworks.com/photos/0530041421_4.jpg'style='width: 100%'   '/>",
#                                 "<img id='sketch1' src = 'https://kimball.gworks.com/photos/0530041421_1.jpg'style='width: 100%' '/>"
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %%
print(len(test['items'][0]['items']))
for item in test['items'][0]['items']:
    #print(json.dumps(item,indent=4))
    print(item['title'])
# Out:
# 11
# Parcel Information
# Assessed Values
# Yearly Tax Information
# 2023 Tax Levy
# Sales Information
# Property Classification
# Land Information
# Residential Datasheet
# Dwelling Data
# Outbuilding Data
# Photo/Sketch

# %%
def get_parcel_info(pid):
    path = f"PID_Details/{pid}_detail.json"
    if os.path.exists(path):
        with open(path) as pid_file:
            [raw_text] = pid_file.readlines()
        data = json.loads(raw_text)
        parcel_data = data['items'][0]['items']
        for item in parcel_data:
            #print(item['title'])
            if item['title'].__contains__('Assessed Values'):
                value_data = item['items']
                for v_item in value_data:
                    print(v_item)
                    if v_item['title'].__contains__("Total"):
                        assessed_totals = v_item['items']
                        print(assessed_totals)

# %%
get_parcel_info(sales_pids[1])
# Out:
# {'type': 'field', 'title': 'Year', 'formtype': 'list', 'HeaderFormat': '', 'items': ['2023', '2022']}
# {'type': 'field', 'title': 'Total', 'formtype': 'list', 'HeaderFormat': '', 'items': ['$193,660', '$163,460']}
# ['$193,660', '$163,460']
# {'type': 'field', 'title': 'Land', 'formtype': 'list', 'HeaderFormat': '', 'items': ['$11,900', '$10,185']}
# {'type': 'field', 'title': 'Outbuilding', 'formtype': 'list', 'HeaderFormat': '', 'items': ['$975', '$810']}
# {'type': 'field', 'title': 'Dwelling', 'formtype': 'list', 'HeaderFormat': '', 'items': ['$180,785', '$152,465']}

# %%
# Get Assessed Value


# Get Sales Info


# Get Residential Datasheet

# %%
def get_parcel_info(pid):
    path = f"PID_Details/{pid}_detail.json"
    sale_price = 
    if os.path.exists(path):
        with open(path) as pid_file:
            [raw_text] = pid_file.readlines()
        data = json.loads(raw_text)
        parcel_data = data['items'][0]['items']
        
        # Extract 'Assessed Values' data, if present
        value_data = next((item['items'] for item in parcel_data if 'Assessed Values' in item['title']), None)
        
        assessed_value = next((v_item['items'] for v_item in value_data if 'Total' in v_item['title']), None)

        # Extract 'Sales Info' data, if present
        sales_data = next((item['items'] for item in parcel_data if 'Sales Info' in item['title']), None)
        if sales_data:
            sale_price = next((s_item['items'] for s_item in sales_data if 'Sale Price' in s_item['title']), None)
        
        # Get Residential Datasheet
        residential_data = next((item['items'] for item in parcel_data if 'Residential Datasheet' in item['title']), None)
        for x in residential_data:
            print(x)
        condition = next((r_item['items'] for r_item in residential_data if 'Condition:' in r_item['title']), None)
        year = next((r_item['items'] for r_item in residential_data if 'Year Built:' in r_item['title']), None)
        bathroom = next((r_item['items'] for r_item in residential_data if 'Bathrooms:' in r_item['title']), None)
        bedroom = next((r_item['items'] for r_item in residential_data if 'Bedrooms:' in r_item['title']), None)
        building_size = next((r_item['items'] for r_item in residential_data if 'Building Size:' in r_item['title']), None)
        """
        for x in sales_data:
            print(x)
        for x in residential_data:
            print(x)
        """
        # Process 'Assessed Values' data
        #print(f"Assessed 2023 Value: {assessed_value[0]}")
        row = [pid, assessed_value[0], year[0], building_size[0], condition[0], bathroom[0], bedroom[0]]
        return row

# %%
get_parcel_info(sales_pids[0])
# Out:
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1945']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Stucco ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.50']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['7']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['336 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['336 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,070 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['252 sq. ft']}
# ['530041421', '$60,885', '1945', '1,070 sq. ft', 'Average', '1.50', '2']

# %%
df = pd.DataFrame(columns = ['pid', 'assessed_value', 'year', 'size', 'condition', 'num_bathrooms', 'num_bedroom'])
for pid in sales_pids:
    try:
        row = get_parcel_info(pid)
        df.loc[len(df)] = row
    except Exception as e:
        print(e)
# Out:
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1945']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Stucco ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.50']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['7']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['336 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['336 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,070 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['252 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1958']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Veneer, Brick ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['9']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,392 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,070 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,820 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Good']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['322 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1953']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Metal ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,442 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1955']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Vinyl ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,038 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Carport, Flat Roof(SF)']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['276 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Good']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1910']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   1 1/2 Story Finished ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Metal ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,204 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['2,101 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage(SF)']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['720 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1917']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Metal ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['624 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['492 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,024 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1942']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Stucco ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Floor Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['304 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['732 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage(SF)']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['400 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1958']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Stucco ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['4']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['896 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['896 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['338 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1981']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Hardboard Sheet ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Singlewide ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warm & Cooled Air ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,064 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1956']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Metal ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,062 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['484 sq. ft']}
# {'items': ['Single Family'], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Low'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1946'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Frame, Siding, Vinyl '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   One Story '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['3'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1.00'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['5'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 100%   Wall Furnace '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,015 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['520 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,015 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1955']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding/Shingle ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,186 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'items': ['Single Family'], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1958'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   One Story '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Frame, Stucco '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2.00'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 24%   Floor Furnace 76%   Forced Air Furnace '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['9'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,262 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Carport, Flat Roof'], 'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Fair'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['400 sq. ft'], 'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Commerical'], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Badly Worn'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1948'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   One Story '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Veneer, Brick '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2.00'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['3'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 100%   Forced Air Furnace '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['10'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['528 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,221 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['693 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,353 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Attached Garage'], 'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Fair'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['275 sq. ft'], 'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1929']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding/Shingle ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['780 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['740 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,120 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage(SF)']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['936 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1955']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Heat Pump ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['936 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['936 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['936 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['308 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1963']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Metal ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['7']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['12']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,360 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,360 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,360 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage(SF)']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['624 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1953']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average - Good']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding/Shingle ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['864 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['2012']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Hardboard Sheets ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['4']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['12']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,705 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,705 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,705 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['837 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1958']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Veneer, Brick ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['9']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['836 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['836 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['836 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['200 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1960']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Stucco ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['182 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['896 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['896 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage(SF)']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1064 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Badly Worn - Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1960']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Vinyl ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['4']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Baseboard, Hot Water ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['11']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,140 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['871 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,140 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['352 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1960']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Vinyl ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,093 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['322 sq. ft']}
# {'items': ['Single Family'], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2008'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   One Story '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['94%   Frame, Siding, Wood 6%   Veneer, Stone '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2.00'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['4'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 100%   Forced Air Furnace '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['12'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,380 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,380 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,380 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Attached Garage'], 'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['720 sq. ft'], 'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Single Family'], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1908'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   1 1/2 Story Finished '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Frame, Siding, Metal '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2.75'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['6'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 100%   Forced Air Furnace '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['11'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['908 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,155 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2,119 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Attached Garage'], 'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['600 sq. ft'], 'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Good']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1959']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Cement Fiber Siding ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['4']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,025 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,025 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,025 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Detached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['441 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1958']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Metal ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['4']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['950 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['169 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,705 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['156 sq. ft']}
# {'items': ['Single Family'], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1976'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   One Story '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Frame, Siding, Vinyl '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['3.00'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['4'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 100%   Warmed & Cooled Air '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['11'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,400 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,200 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,400 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Attached Garage'], 'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['624 sq. ft'], 'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Single Family'], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1960'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Split Level '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Frame, Metal or Vinyl Siding '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2.00'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['4'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 100%   Warmed & Cooled Air '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['10'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['280 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['560 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2,072 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Detached Garage(SF)'], 'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['936 sq. ft'], 'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': ['Single Family']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Good']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1959']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Cement Fiber Siding ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.50']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['7']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,129 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,129 sq. ft']}
# ...
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Floor Furnace ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['390 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,770 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1925']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Hardboard Sheets ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Electric Radiant Heat ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['528 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,312 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1917']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Badly Worn']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Cement Fiber ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['364 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,092 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['2000']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Vinyl ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Warmed & Cooled Air ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['10']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,066 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,066 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,728 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Basement Garage, Double']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['2 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1920']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Stucco ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['1.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['7']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['362 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['165 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,182 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['143 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1987']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Good']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['50%   Frame, Stucco 50%   Veneer, Brick ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['10']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Electric Baseboard ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['144 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['2,116 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['144 sq. ft']}
# {'items': [' '], 'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Good'], 'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1967'], 'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   One Story '], 'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['100%   Frame, Hardboard Sheets '], 'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['2.50'], 'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['4'], 'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': ''}
# {'items': [' 100%   Electric Baseboard '], 'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['12'], 'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['0 sq. ft'], 'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,428 sq. ft'], 'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,176 sq. ft'], 'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['1,428 sq. ft'], 'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Attached Garage'], 'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['Average'], 'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': ''}
# {'items': ['783 sq. ft'], 'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': ''}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1948']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Frame, Siding, Metal ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   1 1/2 Story Finished ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['10']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['874 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,174 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['874 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Fair']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['2008']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Rustic Log ']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   1 1/2 Story Finished ']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,848 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1950']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['50%   Masonry, Stucco on Block 50%   Veneer, Stone ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['3.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['11']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['2,600 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage(SF)']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['960 sq. ft']}
# {'type': 'field', 'title': 'Zoning:', 'formtype': '', 'HeaderFormat': '', 'items': [' ']}
# {'type': 'field', 'title': 'Condition:', 'formtype': '', 'HeaderFormat': '', 'items': ['Badly Worn']}
# {'type': 'field', 'title': 'Year Built:', 'formtype': '', 'HeaderFormat': '', 'items': ['1962']}
# {'type': 'field', 'title': 'Style:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   One Story ']}
# {'type': 'field', 'title': 'Exterior:', 'formtype': '', 'HeaderFormat': '', 'items': ['100%   Veneer, Brick ']}
# {'type': 'field', 'title': 'Bathrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['2.00']}
# {'type': 'field', 'title': 'Bedrooms:', 'formtype': '', 'HeaderFormat': '', 'items': ['5']}
# {'type': 'field', 'title': 'Heating/Cooling:', 'formtype': '', 'HeaderFormat': '', 'items': [' 100%   Forced Air Furnace ']}
# {'type': 'field', 'title': 'Plumbing Fixtures:', 'formtype': '', 'HeaderFormat': '', 'items': ['8']}
# {'type': 'field', 'title': 'Min Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['0 sq. ft']}
# {'type': 'field', 'title': 'Basement Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,440 sq. ft']}
# {'type': 'field', 'title': 'Part Finish:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,440 sq. ft']}
# {'type': 'field', 'title': 'Building Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['1,440 sq. ft']}
# {'type': 'field', 'title': 'Garage 1:', 'formtype': '', 'HeaderFormat': '', 'items': ['Attached Garage']}
# {'type': 'field', 'title': 'Quality:', 'formtype': '', 'HeaderFormat': '', 'items': ['Average']}
# {'type': 'field', 'title': 'Garage 1 Size:', 'formtype': '', 'HeaderFormat': '', 'items': ['660 sq. ft']}

# %%
df = df[df.duplicated("pid", keep=False)]

# %%
sales_df = sales_df.drop_duplicates()
len(sales_df)
# Out:
# 641

# %%
len(df)
# Out:
# 405

# %%
test_df = pd.merge(sales_df, df, left_on="Parcel ID", right_on="pid", how='left')

# %%
test_dupes = test_df[test_df.duplicated(['Sale Date', 'Parcel ID'])]
test_dupes
# Out:
#       Sale Date  Parcel ID                            Seller  \
# 550  2018-10-16  530040824        Larry L & JoAnne M Fleagle
# 552  2018-10-18  530033429          Melvin D & Sarah E Bouse
# 555  2018-10-23  530036703                Patrick H Connelly
# 558  2018-10-26  530043416                   Lisa A Rockhold
# 560  2018-12-14  530035626  Kenneth H & Cynthia Stone Hunter
# ...         ...        ...                               ...
# 1227 2020-10-16  530018705  Brandon M & Chelsea Sue Mossberg
# 1229 2021-01-20  530023830    Eric J & Rebecca J Lichtenberg
# 1232 2021-03-05  530010445                   Daniel B Arnold
# 1235 2021-03-25  530024640           Kathleen Atkins Trustee
# 1237 2021-08-05  530010518          Michael T & Renee A Geha
#
#                                     Buyer  \
# 550                   Christopher J Woods
# 552                        Ka'Lani O'Shea
# 555                      Mary Ann Felkins
# 558    Virginia K, Troy L & Julie E Davis
# 560               Ty M & Jessica S Gibson
# ...                                   ...
# 1227   Wesley Clayton & Jordan Lea Albert
# 1229  Brian W Tisdall & Gregory J Tisdall
# 1232      Timothy Wayne & Dixie Lee Smith
# 1235        Ryan Lukassen & Elyse Schlake
# 1237                            Adam Geha
#
#                                      LEGAL DESCRIPTION   Sale Price  \
# 550   ORIGINAL KIMBALL ADDITION BLOCK 21 LOTS 7 THRU 12     62000.0
# 552               DOWD'S SECOND ADDITION BLOCK - LOT 14     80000.0
# 555                    LEAMINGS ADDITION BLOCK 7 LOT 1      40000.0
# 558                    YANNAYON ADDITION BLOCK 2 LOT 20     75500.0
# 560   KIMBALL HEIGHTS ADDITION N. 23' OF LOT 9 AND A...    189000.0
# ...                                                 ...         ...
# 1227          TRACT IN THE E 1/2 SE 1/4 NE 1/4 32-15-55    175000.0
# 1229                   10.62 A TRACT IN N 1/2 32-16-53      81500.0
# 1232                        PART OF S 1/2 S 1/2 6-14-55    330000.0
# 1235               A TRACT IN THE N 1/2 NE 1/4 25-16-54    265000.0
# 1237          1.907 ACRE IN SE CORNER OF SW 1/4 7-14-55     80000.0
#
#      Assessor Location Assessed Value        pid assessed_value  year  \
# 550            Kimball          40020  530040824        $52,950  1922
# 552            Kimball         102980  530033429       $142,110  1960
# 555            Kimball          18875  530036703        $49,260  1914
# 558            Kimball          67475  530043416        $68,070  1917
# 560            Kimball         171090  530035626       $225,245  1957
# ...                ...            ...        ...            ...   ...
# 1227        Rural Resi         160680  530018705       $162,080  2000
# 1229        Rural Resi          86795  530023830        $83,995  1920
# 1232        Rural Resi         215195  530010445       $256,265  1987
# 1235        Rural Resi         161020  530024640       $257,405  1967
# 1237        Rural Resi          74345  530010518        $88,535  1948
#
#               size       condition num_bathrooms num_bedroom
# 550   1,224 sq. ft         Average          1.00           2
# 552   1,277 sq. ft  Average - Good          1.00           3
# 555     873 sq. ft         Average          1.00           2
# 558   1,084 sq. ft         Average          1.00           3
# 560   2,231 sq. ft         Average          2.50           6
# ...            ...             ...           ...         ...
# 1227  1,728 sq. ft         Average          2.00           3
# 1229  1,182 sq. ft         Average          1.00           2
# 1232  2,116 sq. ft            Good          2.00           5
# 1235  1,428 sq. ft            Good          2.50           4
# 1237  1,174 sq. ft         Average          2.00           5
#
# [130 rows x 15 columns]

# %%
test_df = test_df.drop_duplicates(subset=['Sale Date', 'Parcel ID'])
out_df = test_df.drop(columns=['Seller', 'Buyer', 'Assessed Value', 'pid'])

# %%
out_df.isna().sum()
# Out:
# Sale Date               0
# Parcel ID               0
# LEGAL DESCRIPTION       0
# Sale Price              0
# Assessor Location       0
# assessed_value        244
# year                  244
# size                  244
# condition             244
# num_bathrooms         244
# num_bedroom           244
# dtype: int64

# %%
out_df = out_df.dropna()
out_df
# Out:
#       Sale Date  Parcel ID                                 LEGAL DESCRIPTION   \
# 0    2014-10-17  530041421  SOUTH PARK ADD. BLOCK 3 N 1/2 OF LOT 13 AND AL...
# 2    2014-10-29  530035642                       KIMBALL HEIGHTS ADD. LOT 13
# 6    2014-11-14  530042800           SUNNYVIEW HEIGHTS ADD. BLOCK 13 LOT 14
# 8    2014-11-24  530047381   ANTELOPEVILLE ADD. BLOCK 8 W 1/2 OF LOTS8 AND 9
# 14   2014-12-29  530033798         FAIRVIEW ADD. BLOCK 4 LOTS 21-22-23 AND 24
# ...         ...        ...                                                ...
# 1207 2022-08-11  530031760  ALDENS ADD. BLOCK 1 N. 22' OF LOT 7 AND S. 82'...
# 1212 2022-08-19  530042606             SUNNYVIEW HEIGHTS ADD. BLOCK 12 LOT 10
# 1216 2022-09-09  530036843  LEAMINGS ADD, BLOCK 8 LOT 3 AND THE N 1/2 OF L...
# 1221 2021-10-04  530048191     BOGLES'S ADD BLOCK 1 LOTS 5 AND 6 EXC. N. 40'
# 1241 2022-04-28  530020041  TAX LOT 14 MORGAN'S SUBDIVISION IN E 1/2 OF SW...
#
#       Sale Price Assessor Location assessed_value  year          size  \
# 0        54500.0           Kimball        $60,885  1945  1,070 sq. ft
# 2       140000.0           Kimball       $193,660  1958  1,820 sq. ft
# 6        49600.0           Kimball        $58,850  1955  1,038 sq. ft
# 8       102000.0           Kimball       $118,585  1910  2,101 sq. ft
# 14       20000.0           Kimball        $57,990  1981  1,064 sq. ft
# ...          ...               ...            ...   ...           ...
# 1207    179000.0           Kimball       $187,580  1959  1,670 sq. ft
# 1212    125000.0           Kimball       $143,250  1956  1,051 sq. ft
# 1216    120000.0           Kimball       $102,535  1921  1,078 sq. ft
# 1221     23500.0          Bushnell        $23,495  1929    930 sq. ft
# 1241    305000.0        Rural Resi       $162,135  1950  2,600 sq. ft
#
#        condition num_bathrooms num_bedroom
# 0        Average          1.50           2
# 2        Average          2.00           5
# 6        Average          1.00           3
# 8           Good          2.00           5
# 14       Average          2.00           3
# ...          ...           ...         ...
# 1207     Average          3.00           3
# 1212        Good          2.00           4
# 1216        Good          2.00           3
# 1221  Badly Worn          1.00           2
# 1241     Average          3.00           5
#
# [267 rows x 11 columns]
