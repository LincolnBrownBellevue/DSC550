# %% [markdown]
# ## Housing Sale Price Predictions
#
# ### Term Project
#
# ## Lincoln Brown
#
# ## DSC550-T302
#
# ## Professor Werner

# %%
import pandas as pd
import os
import numpy as np
import re

# %%
files = os.listdir()
file_list = []
years = []
df_list = []

# %%
for f in files:
    if f.__contains__('Resi'):
        file_list.append(f)
        pattern = "(\d{4})-(\d{4})"
        pattern = re.compile(pattern)
        [f_years] = pattern.findall(f)
        print(f_years)
        years.append(f_years)
# Out:
# ('2014', '2016')
# ('2017', '2019')
# ('2015', '2017')
# ('2018', '2020')
# ('2019', '2021')
# ('2016', '2018')
# ('2020', '2022')

# %%
df_14_16 = pd.read_excel(file_list[0], header=0, skiprows=[0,1])
df_17_19 = pd.read_excel(file_list[1], header=0, skiprows=[0,1,3])
df_15_17 = pd.read_excel(file_list[2], header=0, skiprows=[0,1])
df_18_20 = pd.read_excel(file_list[3], header=2, skiprows=[0,1,3])
df_19_21 = pd.read_excel(file_list[4], header=1, skiprows=[0,3])
df_16_18 = pd.read_excel(file_list[5], header=0, skiprows=[0,1])
df_20_22 = pd.read_excel(file_list[6], header=2, skiprows=[0,3])
# Out:
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /home/x/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
# Out:
#      Sale Date    Parcel ID                        Seller  \
# 0   2016-10-13  530045583.0                 James Buckley
# 1   2016-10-17  530041286.0     Charles & Carolyn Carlson
# 2   2016-10-20  530035448.0  James Prince & Nancy Garrett
# 3   2016-10-24  530032546.0                  Claire Tritt
# 4   2016-11-05  530045273.0            Jennifer Dillinger
# ..         ...          ...                           ...
# 137 2018-06-15  530020696.0     Michael H & Karen M Isley
# 138 2018-07-06  530031094.0               Karla J Jenkins
# 139 2018-07-18  530151470.0     Jared C & Melissa L Reich
# 140 2018-08-01  530025779.0               Jeanne Anderson
# 141 2018-09-14  530026937.0              Mary Ann Felkins
#
#                                    Buyer  \
# 0                      Scott Christensen
# 1             Richard & Gloria Brookman
# 2    Patricia Biesecker & Deanna Bleyle
# 3                   Ricky & Julia Gehrig
# 4                            Rachel Rowe
# ...

# %%
df_20_22
# Out:
#      Sale Date    Parcel ID                           Seller  \
# 0   2020-10-01  530033429.0                   Ka'Lani O'Shea
# 1   2020-10-01  530036932.0                Chico R Fernandez
# 2   2020-10-06  530033488.0  Justin W & Jacqueline N Prather
# 3   2020-10-06  530039036.0          James & Donna Cederburg
# 4   2020-10-20  530042959.0                    Carol L Meyer
# ..         ...          ...                              ...
# 137 2021-09-28  530016818.0                Barbara K Michael
# 138 2022-04-11  530015951.0      Sammie M & Lovina Gingerich
# 139 2022-04-28  530020041.0    Michael A & Clara Sue Salazar
# 140 2022-05-11  530151785.0            Jean A Mueller-Yanaga
# 141 2022-07-07  530023288.0               Central Properties
#
#                           Buyer  \
# 0         Sharon June Pickering
# 1               Crystal Kisicki
# 2        Anthony & Linda Madrid
# 3                  Caleb Reuter
# 4                  Danny E Yung
# ...
